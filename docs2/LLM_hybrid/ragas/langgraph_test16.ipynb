# %% [markdown]
# ### 원문 벡터 db + QA 벡터 DB -> 답변 평가 후 -> HyDE 재실행
# ```
# extract_queries → split_queries → tool → qa_tool → basic
# → evaluate ── good → END
#             └─ bad → hyde → tool → qa_tool → basic → evaluate → END
# ```

# %%
from pathlib import Path
import sys

root = Path.cwd()
while not (root / "utils_v9").exists() and root != root.parent:
    root = root.parent
sys.path.insert(0, str(root))

from utils_v9.main3 import (run_langraph)
# Out:
# C:\Users\playdata\Documents\1_ai\LLM_hybrid\utils_v9\retriever.py:51: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vs = Chroma(

# %%
from utils_v9.langgraph_setting2 import graph_setting

graph = graph_setting()

graph
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\teamproject\Lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\langgraph\pregel\main.py:758, in Pregel._repr_mimebundle_(self, **kwargs)
#     754 def _repr_mimebundle_(self, **kwargs: Any) -> dict[str, Any]:
#     755     """Mime bundle used by Jupyter to display the graph"""
#     756     return {
#     757         "text/plain": repr(self),
# --> 758         "image/png": self.get_graph().draw_mermaid_png(),
#     759     }
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\langchain_core\runnables\graph.py:695, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config)
#     687 from langchain_core.runnables.graph_mermaid import draw_mermaid_png
#     689 mermaid_syntax = self.draw_mermaid(
#     690     curve_style=curve_style,
#     691     node_colors=node_colors,
#     692     wrap_label_n_words=wrap_label_n_words,
#     693     frontmatter_config=frontmatter_config,
#     694 )
# --> 695 return draw_mermaid_png(
#     696     mermaid_syntax=mermaid_syntax,
#     697     output_file_path=output_file_path,
#     698     draw_method=draw_method,
#     699     background_color=background_color,
#     700     padding=padding,
#     701     max_retries=max_retries,
#     702     retry_delay=retry_delay,
#     703 )
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:294, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay)
#     288     img_bytes = asyncio.run(
#     289         _render_mermaid_using_pyppeteer(
#     290             mermaid_syntax, output_file_path, background_color, padding
#     291         )
#     292     )
#     293 elif draw_method == MermaidDrawMethod.API:
# --> 294     img_bytes = _render_mermaid_using_api(
#     295         mermaid_syntax,
#     296         output_file_path=output_file_path,
#     297         background_color=background_color,
#     298         max_retries=max_retries,
#     299         retry_delay=retry_delay,
#     300     )
#     301 else:
#     302     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:451, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay)
#     446     # For other status codes, fail immediately
#     447     msg = (
#     448         "Failed to reach https://mermaid.ink/ API while trying to render "
#     449         f"your graph. Status code: {response.status_code}.\n\n"
#     450     ) + error_msg_suffix
# --> 451     raise ValueError(msg)
#     453 except (requests.RequestException, requests.Timeout) as e:
#     454     if attempt < max_retries:
#     455         # Exponential backoff with jitter
#
# ValueError: Failed to reach https://mermaid.ink/ API while trying to render your graph. Status code: 502.
#
# To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %%
response = run_langraph('Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?', '1', None)
# Out:
# run_langraph 호출 - 입력: Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['Firebase의 updateTime 필드에 사용되는 시간 형식은 무엇인가요?', 'What is the time format used in the updateTime field of Firebase?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# C:\Users\playdata\Documents\1_ai\LLM_hybrid\utils_v9\langgraph_node2.py:201: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   results_text = retriever.get_relevant_documents(query)
# 원문 검색 결과: 길이 14개, 첫 문서: | Fields |
# | --- |
# | name | string The resource name of the Database. Format: projects/{project}/dat
# QA 검색 결과: 길이 23개, 첫 문서: Q: Firestore 문서의 생성 시간(createTime)과 업데이트 시간(updateTime)의 형식은 어떻게 되나요?
# A: 두 시간 모두 RFC 3339 형식을 사용하며,
# [vector_search_tool] hybrid 검색 완료: 'Firebase의 updateTime 필드에 사용되는 시간 형식은 무엇인가요?', tags=['firestore']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 13개, 첫 문서: | Fields |
# | --- |
# | name | string The resource name of the Database. Format: projects/{project}/dat
# QA 검색 결과: 길이 24개, 첫 문서: Q: Cloud Firestore 데이터베이스의 업데이트 시간을 확인하는 방법은 무엇인가요?
# A: 데이터베이스의 업데이트 시간은 `updateTime` 필드에서 확인할 수 있습니다
# [vector_search_tool] hybrid 검색 완료: 'What is the time format used in the updateTime field of Firebase?', tags=['firestore']
# [tool_based_search_node] 실행 - state['search_results']=['| Fields |\n| --- |\n| name | string The resource name of the Database. Format: projects/{project}/databases/{database} |\n| uid | string Output only. The system-generated UUID4 for this Database. |\n| create_time | Timestamp Output only. The timestamp at which this database was created. Databases created before 2016 do not populate create_time. |\n| update_time | Timestamp Output only. The timestamp at which this database was most recently updated. Note this only includes updates to the database resource and not data contained by the database. |\n| delete_time | Timestamp Output only. The timestamp at which this database was deleted. Only set if the database has been deleted. |\n| location_id | string The location of the database. Available locations are listed at https://cloud.google.com/firestore/docs/locations. |\n| type | DatabaseType The type of the database. See https://cloud.google.com/datastore/docs/firestore-or-datastore for information about how to choose. |\n| concurrency_mode | ConcurrencyMode The concurrency control mode to use for this database. |', '| deleteTime | string (Timestamp format) Output only. The timestamp at which this database was deleted. Only set if the database has been deleted. Uses RFC 3339, where generated output will always be Z-normalized and use 0, 3, 6 or 9 fractional digits. Offsets other than "Z" are also accepted. Examples: "2014-10-02T15:01:23Z", "2014-10-02T15:01:23.045123456Z" or "2014-10-02T15:01:23+05:30". |\n| locationId | string The location of the database. Available locations are listed at https://cloud.google.com/firestore/docs/locations. |\n| type | enum (DatabaseType) The type of the database. See https://cloud.google.com/datastore/docs/firestore-or-datastore for information about how to choose. |\n| concurrencyMode | enum (ConcurrencyMode) The concurrency control mode to use for this database. |', '웹 버전 9\nimport { doc, setDoc, Timestamp } from "firebase/firestore";\n\nconst docData = {\nstringExample: "Hello world!",\nbooleanExample: true,\nnumberExample: 3.14159265,\ndateExample: Timestamp.fromDate(new Date("December 10, 1815")),\narrayExample: [5, true, "hello"],\nnullExample: null,\nobjectExample: {\na: 5,\nb: {\nnested: "foo"\n}\n}\n};\nawait setDoc(doc(db, "data", "one"), docData);data_types.js [https://github.com/firebase/snippets-web/blob/467eaa165dcbd9b3ab15711e76fa52237ba37f8b/snippets/firestore-next/test-firestore/data_types.js#L8-L24]\n\n웹 버전 8', '--- 탭: Node.js [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#node.js] ---\n```\nconst metadataRef = getDatabase().ref(\'metadata/\' + uid);\nmetadataRef.set({ revokeTime: utcRevocationTimeSecs }).then(() => {\nconsole.log(\'Database updated successfully.\');\n});\n```\n\n--- 탭: 자바 [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#%EC%9E%90%EB%B0%94] ---\n```\nDatabaseReference ref = FirebaseDatabase.getInstance().getReference("metadata/" + uid);\nMap<String, Object> userData = new HashMap<>();\nuserData.put("revokeTime", revocationSecond);\nref.setValueAsync(userData);\n```\n\n--- 탭: Python [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#python] ---\n```\nmetadata_ref = firebase_admin.db.reference("metadata/" + uid)\nmetadata_ref.set({\'revokeTime\': revocation_second})\n```\nFirebase Security Rules에 검사 추가\n\n이 검사를 수행하려면 클라이언트 쓰기 권한 없이 사용자별 취소 시간을\n저장하는 규칙을 설정합니다. 이전 예제와 같이 마지막 취소 시간의\nUTC 타임스탬프로 업데이트하면 됩니다.\n{\n"rules": {\n"metadata": {\n"$user_id": {\n// this could be false as it is only accessed from backend or rules.\n".read": "$user_id === auth.uid",\n".write": "false",\n}\n}\n}\n}', 'Web\nimport { updateDoc, serverTimestamp } from "firebase/firestore";\n\nconst docRef = doc(db, \'objects\', \'some-id\');\n\n// Update the timestamp field with the value from the server\nconst updateTimestamp = await updateDoc(docRef, {\ntimestamp: serverTimestamp()\n});update_with_server_timestamp.js [https://github.com/ ...
# [basic_langgraph_node] 생성된 답변: Firebase의 `updateTime` 필드는 RFC 3339 형식을 사용합니다. 이 형식은 항상 Z-normalized되며 0, 3, 6 또는 9의 소수 자릿수를 사용할 수 있습니다. 예시로는 "2014-10-02T15:01:23Z", "2014-10-02T15:01:23.045123456Z" 또는 "2014-10-02T15:01:23+05:30"가 있습니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?', 'answer': 'Firebase의 `updateTime` 필드는 RFC 3339 형식을 사용합니다. 이 형식은 항상 Z-normalized되며 0, 3, 6 또는 9의 소수 자릿수를 사용할 수 있습니다. 예시로는 "2014-10-02T15:01:23Z", "2014-10-02T15:01:23.045123456Z" 또는 "2014-10-02T15:01:23+05:30"가 있습니다.', 'rewritten': [{'role': 'user', 'content': 'Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?'}], 'queries': ['Firebase의 updateTime 필드에 사용되는 시간 형식은 무엇인가요?', 'What is the time format used in the updateTime field of Firebase?'], 'search_results': ['| Fields |\n| --- |\n| name | string The resource name of the Database. Format: projects/{project}/databases/{database} |\n| uid | string Output only. The system-generated UUID4 for this Database. |\n| create_time | Timestamp Output only. The timestamp at which this database was created. Databases created before 2016 do not populate create_time. |\n| update_time | Timestamp Output only. The timestamp at which this database was most recently updated. Note this only includes updates to the database resource and not data contained by the database. |\n| delete_time | Timestamp Output only. The timestamp at which this database was deleted. Only set if the database has been deleted. |\n| location_id | string The location of the database. Available locations are listed at https://cloud.google.com/firestore/docs/locations. |\n| type | DatabaseType The type of the database. See https://cloud.google.com/datastore/docs/firestore-or-datastore for information about how to choose. |\n| concurrency_mode | ConcurrencyMode The concurrency control mode to use for this database. |', '| deleteTime | string (Timestamp format) Output only. The timestamp at which this database was deleted. Only set if the database has been deleted. Uses RFC 3339, where generated output will always be Z-normalized and use 0, 3, 6 or 9 fractional digits. Offsets other than "Z" are also accepted. Examples: "2014-10-02T15:01:23Z", "2014-10-02T15:01:23.045123456Z" or "2014-10-02T15:01:23+05:30". |\n| locationId | string The location of the database. Available locations are listed at https://cloud.google.com/firestore/docs/locations. |\n| type | enum (DatabaseType) The type of the database. See https://cloud.google.com/datastore/docs/firestore-or-datastore for information about how to choose. |\n| concurrencyMode | enum (ConcurrencyMode) The concurrency control mode to use for this database. |', '웹 버전 9\nimport { doc, setDoc, Timestamp } from "firebase/firestore";\n\nconst docData = {\nstringExample: "Hello world!",\nbooleanExample: true,\nnumberExample: 3.14159265,\ndateExample: Timestamp.fromDate(new Date("December 10, 1815")),\narrayExample: [5, true, "hello"],\nnullExample: null,\nobjectExample: {\na: 5,\nb: {\nnested: "foo"\n}\n}\n};\nawait setDoc(doc(db, "data", "one"), docData);data_types.js [https://github.com/firebase/snippets-web/blob/467eaa165dcbd9b3ab15711e76fa52237ba37f8b/snippets/firestore-next/test-firestore/data_types.js#L8-L24]\n\n웹 버전 8', '--- 탭: Node.js [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#node.js] ---\n```\nconst metadataRef = getDatabase().ref(\'metadata/\' + uid);\nmetadataRef.set({ revokeTime: utcRevocationTimeSecs }).then(() => {\nconsole.log(\'Database updated successfully.\');\n});\n```\n\n--- 탭: 자바 [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#%EC%9E%90%EB%B0%94] ---\n```\nDatabaseReference ref = FirebaseDatabase.getInstance().getReference("metadata/" + uid);\nMap<String, Object> userData = new HashMap<>();\nuserData.put("revokeTime", revocationSecond);\nref.setValueAsync(userData);\n```\n\n--- 탭: Python [https://firebase.google.com/docs/auth/admin/manage-sessions?hl=ko#python] ---\n```\nmetadata_ref = firebase_admin.db.reference("metadata/" + uid)\nmetadata_ref.set({\'revokeTime\': revocation_second})\n```\nFirebase Security Rules에 검사 추가\n\n이 검사를 수행하려면 클라이언트 쓰기 권한 없이 사용자별 취소 시간을\n저장하는 규칙을 설정합니다. 이전 예제와 같이 마지막 취소 시간의\nUTC 타임스탬프로 업데이트하면 됩니다.\n{\n"rules": {\n"metadata": {\n"$user_id": ...

# %%
print(response['answer'])
# Out:
# Firebase의 `updateTime` 필드는 RFC 3339 형식을 사용합니다. 이 형식은 항상 Z-normalized되며 0, 3, 6 또는 9의 소수 자릿수를 사용할 수 있습니다. 예시로는 "2014-10-02T15:01:23Z", "2014-10-02T15:01:23.045123456Z" 또는 "2014-10-02T15:01:23+05:30"가 있습니다.

# %%
response = run_langraph('GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?', '1', None)
print(response)
# Out:
# run_langraph 호출 - 입력: GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?', 'What does the point (0, 0) represent in the GMSMapPoint coordinate system?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Cl
# QA 검색 결과: 길이 25개, 첫 문서: Q: GMSProjection 클래스는 어떤 기능을 제공하나요?
# A: GMSProjection 클래스는 지구 좌표 CLLocationCoordinate2D와 맵 뷰의 좌표 CGPo
# [vector_search_tool] hybrid 검색 완료: 'GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?', tags=['map']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Cl
# QA 검색 결과: 길이 25개, 첫 문서: Q: GMSProjection 클래스는 어떤 기능을 제공하나요?
# A: GMSProjection 클래스는 지구 좌표 CLLocationCoordinate2D와 맵 뷰의 좌표 CGPo
# [vector_search_tool] hybrid 검색 완료: 'What does the point (0, 0) represent in the GMSMapPoint coordinate system?', tags=['map']
# [tool_based_search_node] 실행 - state['search_results']=['GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSProjection]\nDefines a mapping between Earth coordinates CLLocationCoordinate2D and coordinates in the map’s view CGPoint. A projection is constant and immutable, in that the mapping it embodies never changes. The mapping is not necessarily linear.\nPassing invalid Earth coordinates (i.e., per CLLocationCoordinate2DIsValid) to this object may result in undefined behavior.\nThis class should not be instantiated directly unless under testing conditions. Instead, obtain it via projection on GMSMapView [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMapView].\nDeclaration\nSWIFT\nclass GMSProjection : NSObject\nOBJECTIVE-C\n@interface GMSProjection : NSObject\nGMSServices [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSServices]\nService class for the Google Maps SDK for iOS.\nThis class is not thread safe. All methods should only be invoked on the main thread.\nDeclaration\nSWIFT\nclass GMSServices : NSObject\nOBJECTIVE-C\n@interface GMSServices : NSObject', 'Declaration\nSWIFT\nclass GMSMapViewOptions : NSObject\nOBJECTIVE-C\n@interface GMSMapViewOptions : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]\nGMSMarkerLayer is a subclass of GMSOverlayLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlayLayer], available on a per-marker basis, that allows animation of several properties of its associated GMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker].', 'Declaration\nSWIFT\nclass GMSMapStyle : NSObject\nOBJECTIVE-C\n@interface GMSMapStyle : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]', 'GMSAddress [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSAddress]\nA result from a reverse geocode request, containing a human-readable address. This class is immutable and should not be instantiated directly unless under testing circumstances. Obtain an instance via GMSGeocoder [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSGeocoder].\nSome of the fields may be nil, indicating they are not present.\nDeclaration\nSWIFT\nclass GMSAddress : NSObject, NSCopying, NSSecureCoding\nOBJECTIVE-C\n@interface GMSAddress : NSObject <NSCopying, NSSecureCoding>\nGM ...
# [basic_langgraph_node] 생성된 답변: 죄송하지만, 제공된 문서에는 GMSMapPoint의 좌표계에서 (0, 0)이 어떤 지점을 의미하는지에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 대한 답변을 제공할 수 없습니다. 다른 질문이 있으시면 말씀해 주세요.
# [evaluate_answer_node] 평가 결과: bad
# [evaluate_answer_node] 최종 : bad
# [generate_alternative_queries] 생성된 쿼리: ['GMSMapPoint의 좌표계에서 (0, 0)은 지구의 좌측 상단 모서리를 의미합니다. 이는 Google Maps API에서 사용되는 Mercator 투영법에 기반한 좌표계로, (0, 0)은 일반적으로 북서쪽 끝을 나타냅니다.', 'In the coordinate system of GMSMapPoint, (0, 0) represents the top-left corner of the Earth. This is based on the Mercator projection used in the Google Maps API, where (0, 0) typically indicates the northwesternmost point.']
# [tool_based_search_node] 실행 - queries=['GMSMapPoint의 좌표계에서 (0, 0)은 지구의 좌측 상단 모서리를 의미합니다. 이는 Google Maps API에서 사용되는 Mercator 투영법에 기반한 좌표계로, (0, 0)은 일반적으로 북서쪽 끝을 나타냅니다.', 'In the coordinate system of GMSMapPoint, (0, 0) represents the top-left corner of the Earth. This is based on the Mercator projection used in the Google Maps API, where (0, 0) typically indicates the northwesternmost point.']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 17개, 첫 문서: 세계 좌표
# API는 세계의 한 위치를 지도상의 위치로 변환해야 할 때마다 먼저 위도와 경도 값을 세계 좌표로 변환합니다. 변환에는 메르카토르 투영법 [https://en.wikip
# QA 검색 결과: 길이 44개, 첫 문서: Q: Google 지도에서 세계 좌표는 어떤 기준으로 측정되나요?
# A: Google 지도에서 세계 좌표는 메르카토르 투영의 원점(경도 180도와 위도 약 85도에 있는 지도의 북서
# [vector_search_tool] hybrid 검색 완료: 'GMSMapPoint의 좌표계에서 (0, 0)은 지구의 좌측 상단 모서리를 의미합니다. 이는 Google Maps API에서 사용되는 Mercator 투영법에 기반한 좌표계로, (0, 0)은 일반적으로 북서쪽 끝을 나타냅니다.', tags=['map']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 19개, 첫 문서: 세계 좌표
# API는 세계의 한 위치를 지도상의 위치로 변환해야 할 때마다 먼저 위도와 경도 값을 세계 좌표로 변환합니다. 변환에는 메르카토르 투영법 [https://en.wikip
# QA 검색 결과: 길이 44개, 첫 문서: Q: Google 지도에서 세계 좌표는 어떤 기준으로 측정되나요?
# A: Google 지도에서 세계 좌표는 메르카토르 투영의 원점(경도 180도와 위도 약 85도에 있는 지도의 북서
# [vector_search_tool] hybrid 검색 완료: 'In the coordinate system of GMSMapPoint, (0, 0) represents the top-left corner of the Earth. This is based on the Mercator projection used in the Google Maps API, where (0, 0) typically indicates the northwesternmost point.', tags=['map']
# [tool_based_search_node] 실행 - state['search_results']=['GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSProjection]\nDefines a mapping between Earth coordinates CLLocationCoordinate2D and coordinates in the map’s view CGPoint. A projection is constant and immutable, in that the mapping it embodies never changes. The mapping is not necessarily linear.\nPassing invalid Earth coordinates (i.e., per CLLocationCoordinate2DIsValid) to this object may result in undefined behavior.\nThis class should not be instantiated directly unless under testing conditions. Instead, obtain it via projection on GMSMapView [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMapView].\nDeclaration\nSWIFT\nclass GMSProjection : NSObject\nOBJECTIVE-C\n@interface GMSProjection : NSObject\nGMSServices [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSServices]\nService class for the Google Maps SDK for iOS.\nThis class is not thread safe. All methods should only be invoked on the main thread.\nDeclaration\nSWIFT\nclass GMSServices : NSObject\nOBJECTIVE-C\n@interface GMSServices : NSObject', 'Declaration\nSWIFT\nclass GMSMapViewOptions : NSObject\nOBJECTIVE-C\n@interface GMSMapViewOptions : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]\nGMSMarkerLayer is a subclass of GMSOverlayLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlayLayer], available on a per-marker basis, that allows animation of several properties of its associated GMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker].', 'Declaration\nSWIFT\nclass GMSMapStyle : NSObject\nOBJECTIVE-C\n@interface GMSMapStyle : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]', 'GMSAddress [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSAddress]\nA result from a reverse geocode request, containing a human-readable address. This class is immutable and should not be instantiated directly unless under testing circumstances. Obtain an instance via GMSGeocoder [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSGeocoder].\nSome of the fields may be nil, indicating they are not present.\nDeclaration\nSWIFT\nclass GMSAddress : NSObject, NSCopying, NSSecureCoding\nOBJECTIVE-C\n@interface GMSAddress : NSObject <NSCopying, NSSecureCoding>\nGM ...
# [basic_langgraph_node] 생성된 답변: GMSMapPoint의 좌표계에서 (0, 0)은 Google 지도에서 메르카토르 투영의 원점, 즉 경도 180도와 위도 약 85도에 있는 지도의 북서쪽 모서리를 의미합니다. 이 지점에서 x 방향으로 동쪽(오른쪽)으로 증가하고, y 방향으로 남쪽(아래쪽)으로 증가합니다.
# [evaluate_answer_node] 평가 결과: bad
# [evaluate_answer_node] 최종 : final
# 그래프 실행 결과: {'question': 'GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?', 'answer': 'GMSMapPoint의 좌표계에서 (0, 0)은 Google 지도에서 메르카토르 투영의 원점, 즉 경도 180도와 위도 약 85도에 있는 지도의 북서쪽 모서리를 의미합니다. 이 지점에서 x 방향으로 동쪽(오른쪽)으로 증가하고, y 방향으로 남쪽(아래쪽)으로 증가합니다.', 'rewritten': [{'role': 'user', 'content': 'GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?'}], 'queries': ['GMSMapPoint의 좌표계에서 (0, 0)은 지구의 좌측 상단 모서리를 의미합니다. 이는 Google Maps API에서 사용되는 Mercator 투영법에 기반한 좌표계로, (0, 0)은 일반적으로 북서쪽 끝을 나타냅니다.', 'In the coordinate system of GMSMapPoint, (0, 0) represents the top-left corner of the Earth. This is based on the Mercator projection used in the Google Maps API, where (0, 0) typically indicates the northwesternmost point.'], 'search_results': ['GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSProjection]\nDefines a mapping between Earth coordinates CLLocationCoordinate2D and coordinates in the map’s view CGPoint. A projection is constant and immutable, in that the mapping it embodies never changes. The mapping is not necessarily linear.\nPassing invalid Earth coordinates (i.e., per CLLocationCoordinate2DIsValid) to this object may result in undefined behavior.\nThis class should not be instantiated directly unless under testing conditions. Instead, obtain it via projection on GMSMapView [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMapView].\nDeclaration\nSWIFT\nclass GMSProjection : NSObject\nOBJECTIVE-C\n@interface GMSProjection : NSObject\nGMSServices [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSServices]\nService class for the Google Maps SDK for iOS.\nThis class is not thread safe. All methods should only be invoked on the main thread.\nDeclaration\nSWIFT\nclass GMSServices : NSObject\nOBJECTIVE-C\n@interface GMSServices : NSObject', 'Declaration\nSWIFT\nclass GMSMapViewOptions : NSObject\nOBJECTIVE-C\n@interface GMSMapViewOptions : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]\nGMSMarkerLayer is a subclass of GMSOverlayLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlayLayer], available on a per-marker basis, that allows animation of several properties of its associated GMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker].', 'Declaration\nSWIFT\nclass GMSMapStyle : NSObject\nOBJECTIVE-C\n@interface GMSMapStyle : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]', ' ...
# {'question': 'GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?', 'answer': 'GMSMapPoint의 좌표계에서 (0, 0)은 Google 지도에서 메르카토르 투영의 원점, 즉 경도 180도와 위도 약 85도에 있는 지도의 북서쪽 모서리를 의미합니다. 이 지점에서 x 방향으로 동쪽(오른쪽)으로 증가하고, y 방향으로 남쪽(아래쪽)으로 증가합니다.', 'rewritten': [{'role': 'user', 'content': 'GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?'}], 'queries': ['GMSMapPoint의 좌표계에서 (0, 0)은 지구의 좌측 상단 모서리를 의미합니다. 이는 Google Maps API에서 사용되는 Mercator 투영법에 기반한 좌표계로, (0, 0)은 일반적으로 북서쪽 끝을 나타냅니다.', 'In the coordinate system of GMSMapPoint, (0, 0) represents the top-left corner of the Earth. This is based on the Mercator projection used in the Google Maps API, where (0, 0) typically indicates the northwesternmost point.'], 'search_results': ['GMSProjection [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSProjection]\nDefines a mapping between Earth coordinates CLLocationCoordinate2D and coordinates in the map’s view CGPoint. A projection is constant and immutable, in that the mapping it embodies never changes. The mapping is not necessarily linear.\nPassing invalid Earth coordinates (i.e., per CLLocationCoordinate2DIsValid) to this object may result in undefined behavior.\nThis class should not be instantiated directly unless under testing conditions. Instead, obtain it via projection on GMSMapView [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMapView].\nDeclaration\nSWIFT\nclass GMSProjection : NSObject\nOBJECTIVE-C\n@interface GMSProjection : NSObject\nGMSServices [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSServices]\nService class for the Google Maps SDK for iOS.\nThis class is not thread safe. All methods should only be invoked on the main thread.\nDeclaration\nSWIFT\nclass GMSServices : NSObject\nOBJECTIVE-C\n@interface GMSServices : NSObject', 'Declaration\nSWIFT\nclass GMSMapViewOptions : NSObject\nOBJECTIVE-C\n@interface GMSMapViewOptions : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]\nGMSMarkerLayer is a subclass of GMSOverlayLayer [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSOverlayLayer], available on a per-marker basis, that allows animation of several properties of its associated GMSMarker [https://developers.google.com/maps/documentation/ios-sdk/reference/objc/Classes/GMSMarker].', 'Declaration\nSWIFT\nclass GMSMapStyle : NSObject\nOBJECTIVE-C\n@interface GMSMapStyle : NSObject\nGMSMarker [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarker]\nA marker is an icon placed at a particular point on the map’s surface. A marker’s icon is drawn oriented against the device’s screen rather than the map’s surface; i.e., it will not necessarily change orientation due to map rotations, tilting, or zooming.\nDeclaration\nSWIFT\nclass GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nOBJECTIVE-C\n@interface GMSMarker : GMSOverlay [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSOverlay]\nGMSMarkerLayer [https://developers.google.com/maps/documentation/navigation/ios-sdk/reference/objc/Classes/GMSMarkerLayer]', 'GMSAddress  ...

# %%
print(response['answer'])
# # print(response['tool_calls'])
# print(response['qa_tool_calls'])
# Out:
# GMSMapPoint의 좌표계에서 (0, 0)은 Google 지도에서 메르카토르 투영의 원점, 즉 경도 180도와 위도 약 85도에 있는 지도의 북서쪽 모서리를 의미합니다. 이 지점에서 x 방향으로 동쪽(오른쪽)으로 증가하고, y 방향으로 남쪽(아래쪽)으로 증가합니다.

# %%
response = run_langraph('MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하나요?', '1', None)
# Out:
# run_langraph 호출 - 입력: MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일을 직접 수정해야 하나요?', 'Do I need to directly modify the config.json file to configure the cover of MAP 3D storytelling?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]
# 스타일 편집
# QA 검색 결과: 길이 22개, 첫 문서: Q: JSON 스타일 지정을 사용하여 지도를 수동으로 맞춤설정하는 방법은 무엇인가요?
# A: 지도를 수동으로 맞춤설정하면 일반 지도 유형의 스타일을 지정할 수 있으며 지도 ID가 필
# [vector_search_tool] hybrid 검색 완료: 'MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일을 직접 수정해야 하나요?', tags=['map']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: assignment [https://developers.google.com/maps/architecture/3d-storytelling-customizations?hl=ko]
# 맞춤
# QA 검색 결과: 길이 23개, 첫 문서: Q: JSON 스타일 지정을 사용하여 지도를 수동으로 맞춤설정하는 방법은 무엇인가요?
# A: 지도를 수동으로 맞춤설정하면 일반 지도 유형의 스타일을 지정할 수 있으며 지도 ID가 필
# [vector_search_tool] hybrid 검색 완료: 'Do I need to directly modify the config.json file to configure the cover of MAP 3D storytelling?', tags=['map']
# [tool_based_search_node] 실행 - state['search_results']=["downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/javascript/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/maps-static/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/ios-sdk/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", '여러 앱에서 동일한 스타일을 업데이트하려면 Google Cloud 콘솔에서 사용할 수 있고 지도 ID [https://developers.google.com/maps/documentation/get-map-id?hl=ko]가 필요한 클라우드 맞춤설정 [https://developers.google.com/maps/documentation/ios-sdk/cloud-customization?hl=ko]을 살펴보세요. 잠재적인 충돌을 방지하려면 동일한 앱에서 클라우드 맞춤설정과 하드코딩된 스타일 지정을 결합 ...
# [basic_langgraph_node] 생성된 답변: 죄송하지만, 제공된 문서에는 MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일을 직접 수정하는 방법에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 대한 답변을 제공할 수 없습니다. 다른 질문이 있으시면 말씀해 주세요.
# [evaluate_answer_node] 평가 결과: bad
# [evaluate_answer_node] 최종 : bad
# [generate_alternative_queries] 생성된 쿼리: ['Google Maps API에서 3D 스토리텔링을 구성하기 위해 config.json 파일을 직접 수정할 필요는 없습니다. 대신, Google Maps JavaScript API를 사용하여 지도 스타일과 3D 요소를 동적으로 설정할 수 있습니다.', "For configuring 3D storytelling in Google Maps API, you don't need to directly modify the config.json file. Instead, you can use the Google Maps JavaScript API to dynamically set map styles and 3D elements."]
# [tool_based_search_node] 실행 - queries=['Google Maps API에서 3D 스토리텔링을 구성하기 위해 config.json 파일을 직접 수정할 필요는 없습니다. 대신, Google Maps JavaScript API를 사용하여 지도 스타일과 3D 요소를 동적으로 설정할 수 있습니다.', "For configuring 3D storytelling in Google Maps API, you don't need to directly modify the config.json file. Instead, you can use the Google Maps JavaScript API to dynamically set map styles and 3D elements."]
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 19개, 첫 문서: 이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.
# Maps JavaScrip
# QA 검색 결과: 길이 42개, 첫 문서: Q: Google Maps JavaScript API에서 3D 맵을 구현하는 방법은 무엇인가요?
# A: 3D 맵을 구현하기 위해서는 Google Maps JavaScript API의
# [vector_search_tool] hybrid 검색 완료: 'Google Maps API에서 3D 스토리텔링을 구성하기 위해 config.json 파일을 직접 수정할 필요는 없습니다. 대신, Google Maps JavaScript API를 사용하여 지도 스타일과 3D 요소를 동적으로 설정할 수 있습니다.', tags=['map']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 20개, 첫 문서: Google Maps Platform API의 맞춤 스타일 만들기 [https://mapstyle.withgoogle.com/]
# 지도 플랫폼 스타일 지정 마법사 [https://m
# QA 검색 결과: 길이 44개, 첫 문서: Q: Google Maps JavaScript API에서 3D 맵을 구현하는 방법은 무엇인가요?
# A: 3D 맵을 구현하기 위해서는 Google Maps JavaScript API의
# [vector_search_tool] hybrid 검색 완료: 'For configuring 3D storytelling in Google Maps API, you don't need to directly modify the config.json file. Instead, you can use the Google Maps JavaScript API to dynamically set map styles and 3D elements.', tags=['map']
# [tool_based_search_node] 실행 - state['search_results']=["downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/javascript/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/maps-static/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/ios-sdk/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", '여러 앱에서 동일한 스타일을 업데이트하려면 Google Cloud 콘솔에서 사용할 수 있고 지도 ID [https://developers.google.com/maps/documentation/get-map-id?hl=ko]가 필요한 클라우드 맞춤설정 [https://developers.google.com/maps/documentation/ios-sdk/cloud-customization?hl=ko]을 살펴보세요. 잠재적인 충돌을 방지하려면 동일한 앱에서 클라우드 맞춤설정과 하드코딩된 스타일 지정을 결합 ...
# [basic_langgraph_node] 생성된 답변: 죄송하지만, 제공된 문서에는 "MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하는지"에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 대한 답변을 제공할 수 없습니다. 다른 질문이 있으시면 말씀해 주세요.
# [evaluate_answer_node] 평가 결과: bad
# [evaluate_answer_node] 최종 : final
# 그래프 실행 결과: {'question': 'MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하나요?', 'answer': '죄송하지만, 제공된 문서에는 "MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하는지"에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 대한 답변을 제공할 수 없습니다. 다른 질문이 있으시면 말씀해 주세요.', 'rewritten': [{'role': 'user', 'content': 'MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하나요?'}], 'queries': ['Google Maps API에서 3D 스토리텔링을 구성하기 위해 config.json 파일을 직접 수정할 필요는 없습니다. 대신, Google Maps JavaScript API를 사용하여 지도 스타일과 3D 요소를 동적으로 설정할 수 있습니다.', "For configuring 3D storytelling in Google Maps API, you don't need to directly modify the config.json file. Instead, you can use the Google Maps JavaScript API to dynamically set map styles and 3D elements."], 'search_results': ["downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/javascript/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/maps-static/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nvariant\n'light'|'dark' 밝은 모드 또는 어두운 모드를 지정합니다. 지정하지 않으면 기본값은 'light'입니다. 'light'\nmonochrome\n부울 흑백을 사용 설정하려면 지도의 회색 버전에 true를 사용하세요.\ntrue\n스타일 규칙 객체\n이 섹션에서는 styles 배열에서 스타일 규칙 객체를 정의하여 지도 기능을 맞춤설정하는 속성을 설명합니다. 각 스타일 규칙 객체는 다음으로 구성되어야 합니다.\nid 속성입니다.\n연결된 스타일러 속성이 정의된 geometry 또는 label 요소\nid (지도 기능)\nid 속성은 스타일을 지정할 지도 기능을 지정합니다. 속성 이름은 스타일 편집기의 지도 기능 이름의 카멜케이스 버전입니다.", "downloadJSON 스키마 다운로드 [https://developers.google.com/static/maps/cbms-json-schema.json?hl=ko]\n스타일 편집기 내에서 JSON을 사용하여 지도 스타일을 수정하거나 지도 스타일을 가져오고 내보내는 방법을 알아보려면 클라우드 기반 지도 스타일 지정에 JSON 사용 [https://developers.google.com/maps/documentation/ios-sdk/cloud-customization/json?hl=ko]을 참고하세요.\nJSON 스타일 선언의 예 보기\nJSON 객체\nJSON 스타일 선언은 최상위 객체와 스타일 규칙 배열로 구성됩니다.\n최상위 설정 (선택사항) - backgroundColor, variant과 같은 전역 스타일 설정입니다.\nstyles - 스타일 규칙 객체의 배열로, 다음으로 구성될 수 있습니다.\nid: 이 스타일 수정에서 선택할 지도 지형지물입니다(예: pointOfInterest.recreation.park)에 복사합니다.\ngeometry (선택사항) - 지도 지형지물의 기하학적 요소와 적용할 스타일 규칙입니다 (예: fillColor)에 복사합니다.\nlabel (선택사항) - 지도 지형지물의 텍스트 또는 핀 라벨과 적용할 스타일 규칙입니다 (예: textStrokeColor)에 복사합니다.\n최상위 수준 설정\n다음 표의 속성은 전체 지도 스타일에 적용됩니다.\n속성 유형 설명 예\nbackgroundColor\n문자열 #RRGGBB 16진수 문자열을 사용하여 지도 앱의 배경색을 맞춤설정합니다. 이 설정은 불투명도 변경을 지원하지 않습니다. '#002211'\nv ...

# %%
print(response['answer'])
# Out:
# 죄송하지만, 제공된 문서에는 "MAP 3D 스토리텔링의 표지를 구성하기 위해 config.json 파일에 직접해야 하는지"에 대한 정보가 포함되어 있지 않습니다. 따라서 이 질문에 대한 답변을 제공할 수 없습니다. 다른 질문이 있으시면 말씀해 주세요.

# %%
## 환경설정
# !pip install -qU ragas langchain langchain-community langchain-openai langchain-chroma langchain-text-splitters pypdf rapidfuzz langgraph gdown chromadb langchain-huggingface sentence-transformers -q

# %%
# !pip install ragas

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# 필요한 라이브러리 임포트
import os
import pandas as pd
from pprint import pprint
# LangChain 관련 라이브러리
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
# RAGAS 관련 라이브러리
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.testset.persona import Persona
from ragas.testset import TestsetGenerator
from ragas import EvaluationDataset, evaluate
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness

# %% [markdown]
# ## 이미 생성된 합성 데이터셋 생성

# %%
import pandas as pd

# 같은 폴더(현재 작업 디렉토리)에 저장했다면
dataset_df = pd.read_csv("./dataset2.csv")
print(dataset_df.shape)
display(dataset_df)
# Out:
# (20, 4)
#                                            user_input  \
# 0        CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?
# 1                       클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?
# 2                                     범위 많으면 동의 어렵나요?
# 3   As a beginner who is not familiar with Google ...
# 4   firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Fire...
# 5   Firebase에서 다단계 인증(MFA)을 사용할 때 Objective-C로 사용자...
# 6       Java를 사용해서 Firestore에 문서를 추가할 때 어떤 코드를 사용하나요?
# 7                   COLUMNS가 Dimension API에서 무슨 뜻인가요?
# 8                          ttll이 뭐에요? 그리고 한도 같은거 있나요?
# 9   Me want know what FUNCTION_ENTRYPOINT do in gc...
# 10                     Google 피트니스 심박수 데이터 읽기 권한 범위는?
# 11    projets.databeses.gte 메서드 쓸때 HTTP 리퀘스트 포맷이 뭐에요?
# 12  Google Developers Console을 활용하여 YouTube Data A...
# 13  firsetore users 데이타 가져오려면 어떻게하나요? users 콜렉션에서 ...
# 14                    Python에서 Cloud Firestore 초기화 방법
# 15  BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하고자 할 때, ...
# 16                         itemDownlodRestrction 뭐에요?
# 17  What does the textFormat field represent in Tr...
# 18                                 fileId는 무엇을 의미하나요?
# 19  Gmail 작업을 선언하는 방법에 대해 자세히 알고 싶은데, Declaring Ac...
#
#                                    reference_contexts  \
# 0   ['Q: S/MIME 인증서를 관리하기 위해 CSV 파일을 처리하는 함수에서 어떤 ...
# 1   ['Q: Cloud Firestore의 부하 분산 기능은 어떻게 작동하나요?\nA:...
# 2   ['Q: OAuth 2.0을 사용할 때 요청하는 범위의 수가 사용자 동의에 미치는 ...
# 3   ['Q: Google Cloud 세션 제어 기능이란 무엇이며, 어떤 영향을 미치나요...
# 4   ['Q: Cloud Firestore에서 특정 문서의 모든 변경에 대해 이벤트를 트...
# 5   ['Q: 다단계 인증(MFA) 사용 시 Firebase에서 사용자 인증을 완료하는 ...
# 6   ['Q: Firestore에서 문서에 데이터를 추가할 때 사용하는 Java 코드 예...
# 7   ['Q: Dimension API에서 사용할 수 있는 열거형 값은 무엇인가요?\nA...
# 8   ['Q: TTL 정책을 적용할 때 한도 및 제약조건은 무엇인가요?\nA: 컬렉션 그...
# 9   ['Q: gcloud CLI를 사용하여 Cloud Run 함수를 배포한 후 트리거를...
# 10  ['Q: Google 피트니스에서 심박수 데이터를 확인하기 위해 필요한 OAuth ...
# 11  ['Q: projects.databases.get 메서드를 호출할 때 필요한 HTT...
# 12  ['Q: YouTube Data API를 사용 설정하기 위한 첫 번째 단계는 무엇인...
# 13  ['Q: Firestore에서 데이터를 가져오는 방법은 무엇인가요?\nA: Fire...
# 14  ["Q: Cloud Firestore를 Python에서 서비스 계정을 사용하여 초기...
# 15  ["Q: BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하려면 ...
# 16  ["Q: 파일의 다운로드 제한이 소유자 또는 주최자가 직접 적용한 것인지 확인하려면...
# 17  ['Q: TreemapChartSpec의 JSON 표현에서 textFormat 필드...
# 18  ['Q: AccessProposal을 ID로 검색하는 API 요청은 어떻게 하나요?...
# 19  ['Q: Gmail의 작업 선언 방법에 대한 자료는 어디에서 찾을 수 있나요?\nA...
#
#                                             reference  \
# 0   CSV 파일을 처리하는 함수에서는 사용자의 인증서를 나열하고, 기본 인증서가 만료되...
# 1   Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 ...
# 2           요청된 범위 수가 많으면 사용자 동의를 얻을 가능성이 낮아질 수 있습니다.
# 3   When Google Cloud session control features are...
# 4   Cloud Firestore에서 특정 문서의 모든 변경에 이벤트를 트리거하려면 on...
# 5   다단계 인증(MFA) 사용 시 Firebase에서 사용자 인증을 완료하는 방법은 F...
# 6   다음은 Java에서 Firestore에 문서를 추가할 때 사용하는 코드 예시입니다....
# 7        COLUMNS는 Dimension API에서 시트의 열에서 작동함을 의미합니다.
# 8   컬렉션 그룹당 하나의 필드만 TTL 필드로 표시할 수 있고, 필드 수준 구성은 최대...
# 9   FUNCTION_ENTRYPOINT는 gcloud run deploy 명령어에서 함...
# 10  Google 피트니스에서 심박수 데이터를 확인하기 위해 필요한 OAuth 2.0 범...
# 11  HTTP 요청 형식은 다음과 같습니다:\r\n```\r\nGET https://fi...
# 12  YouTube Data API를 사용 설정하기 위한 첫 번째 단계는 Google D...
# 13  Firestore에서 users 콜렉션의 모든 users 정보를 가져오려면 다음과 ...
# 14  Cloud Firestore를 Python에서 서비스 계정을 사용하여 초기화하려면 ...
# 15  BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하려면 'para...
# 16  itemDownloadRestriction 필드는 소유자 또는 주최자가 직접 적용한...
# 17  The textFormat field specifies the text format...
# 18                             fileId는 파일의 ID를 의미합니다.
# 19  작업 선언 방법에 대한 자세한 내용은 작업 선언(Declaring Actions) ...
#
#                          synthesizer_name
# 0   single_hop_specific_query_synthesizer
# 1   single_hop_specific_query_synthesizer
# 2   single_hop_specific_query_synthesizer
# 3   single_hop_specific_query_synthesizer
# 4   single_hop_specific_query_synthesizer
# 5   single_hop_specific_query_synthesizer
# 6   single_hop_specific_query_synthesizer
# 7   single_hop_specific_query_synthesizer
# 8   single_hop_specific_query_synthesizer
# 9   single_hop_specific_query_synthesizer
# 10  single_hop_specific_query_synthesizer
# 11  single_hop_specific_query_synthesizer
# 12  single_hop_specific_query_synthesizer
# 13  single_hop_specific_query_synthesizer
# 14  single_hop_specific_query_synthesizer
# 15  single_hop_specific_query_synthesizer
# 16  single_hop_specific_query_synthesizer
# 17  single_hop_specific_query_synthesizer
# 18  single_hop_specific_query_synthesizer
# 19  single_hop_specific_query_synthesizer

# %%
## 02.RAG 체인 구성

import pandas as pd
from datasets import Dataset
import uuid
import time


evaluated_dataset = []

for _, row in dataset_df.iterrows():
    time.sleep(3)
    query = row.user_input  # 사용자 입력 - 합성 데이터셋에서 가져옴

    # run_langraph 함수 호출
    rag_result = run_langraph(query,'1', None)

    evaluated_dataset.append(
        {
            "user_input": query,
            "retrieved_contexts": [doc for doc in rag_result["search_results_final"]],
            "response": rag_result["answer"],
            "reference": row['reference']
        }
    )

print("평가 데이터셋 준비 완료")

# RAGAS 평가 데이터셋 생성
ragas_evaluated_dataset = Dataset.from_list(evaluated_dataset)
# csv 데이터 저장
# ragas_evaluated_dataset.to_pandas().to_csv('ragas_evaluated_dataset_hybrid4.csv', index=False)
ragas_evaluated_dataset.to_pandas().info()
# Out:
# run_langraph 호출 - 입력: CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['CSV 파일을 사용하여 S/MIME 인증서를 관리하는 방법은 무엇인가요?', 'How can I manage S/MIME certificates using a CSV file?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 10개, 첫 문서: except (OSError, IOError) as error:
#     print(f"An error occured while reading the CSV file: {error}
# QA 검색 결과: 길이 20개, 첫 문서: Q: 여러 사용자의 S/MIME 인증서를 한 번에 관리하기 위해 어떤 방법을 사용할 수 있나요?
# A: 여러 사용자의 S/MIME 인증서를 한 번에 관리하기 위해 CSV 파일을 사용
# [vector_search_tool] hybrid 검색 완료: 'CSV 파일을 사용하여 S/MIME 인증서를 관리하는 방법은 무엇인가요?', tags=['gmail']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 11개, 첫 문서: --- 탭: Python ---
# 이전의 create_smime_info 및 insert_smime_info 호출을 사용하여 CSV 파일에 지정된 인증서를 업로드할 수 있습니다.
#
#
# QA 검색 결과: 길이 20개, 첫 문서: Q: 여러 사용자의 S/MIME 인증서를 한 번에 관리하기 위해 어떤 방법을 사용할 수 있나요?
# A: 여러 사용자의 S/MIME 인증서를 한 번에 관리하기 위해 CSV 파일을 사용
# [vector_search_tool] hybrid 검색 완료: 'How can I manage S/MIME certificates using a CSV file?', tags=['gmail']
# [tool_based_search_node] 실행 - state['search_results']=['except (OSError, IOError) as error:\n    print(f"An error occured while reading the CSV file: {error}")\n\n\nif __name__ == "__main__":\n  insert_cert_from_csv(csv_filename="xyz")\n인증서 관리\n이 예에서는 smimeInfo API의 여러 호출을 결합하여 조직의 인증서를 관리하는 방법을 보여줍니다. 사용자의 인증서를 나열하고 기본 인증서가 만료되었거나 설정되지 않은 경우 지정된 파일에서 찾은 인증서를 업로드합니다. 그런 다음 만료일이 가장 늦은 인증서를 기본값으로 설정합니다.\n그런 다음 이전 예와 같이 CSV 파일을 처리하는 함수에서 이를 호출합니다.\n--- 탭: 자바 ---\n.filepath {\n    color: #fff;\n    margin: 6px;\n    max-width: calc(100% - 160px); /* Give at least 160px for the "View on GitHub" button. */\n    text-overflow: ellipsis;\n    text-shadow: rgba(0,0,0,0.1) 1px 1px;\n    overflow: hidden;\n  }\n  .github-docwidget-gitinclude-code .prettyprint {\n    margin: 0;\n  }\n  .view-on-github {\n    text-shadow: rgba(12,12,12,0.1) 1px 1px;\n  }\n\n\n\n  \n  gmail/snippets/src/main/java/UpdateSmimeCerts.java\n  \n    \n    GitHub에서 보기 [https://github.com/googleworkspace/java-samples/blob/main/gmail/snippets/src/main/java/UpdateSmimeCerts.java]', '--- 탭: Python ---\n이전의 create_smime_info 및 insert_smime_info 호출을 사용하여 CSV 파일에 지정된 인증서를 업로드할 수 있습니다.\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n  \n  \n\n\n\n\n\n\n\n\n\n\n\n  .filepath {\n    color: #fff;\n    margin: 6px;\n    max-width: calc(100% - 160px); /* Give at least 160px for the "View on GitHub" button. */\n    text-overflow: ellipsis;\n    text-shadow: rgba(0,0,0,0.1) 1px 1px;\n    overflow: hidden;\n  }\n  .github-docwidget-gitinclude-code .prettyprint {\n    margin: 0;\n  }\n  .view-on-github {\n    text-shadow: rgba(12,12,12,0.1) 1px 1px;\n  }\n\n\n\n  \n  gmail/snippet/smime snippets/insert_cert_from_csv.py\n  \n    \n    GitHub에서 보기 [https://github.com/googleworkspace/python-samples/blob/main/gmail/snippet/smime%20snippets/insert_cert_from_csv.py]\n  \n  \n  \n\n  \n    \n  \n  \n  import csv\n\nimport create_smime_info\nimport insert_smime_info\n\n\ndef insert_cert_from_csv(csv_filename):\n  """Upload S/MIME certificates based on the contents of a CSV file.\n  Each row of the CSV file should contain a user ID, path to the certificate,\n  and the certificate password.\n\n  Args:\n    csv_filename: Name of the CSV file.\n  """', "이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\nS/MIME 인증서 관리\nbookmark_border\n이 페이지의 내용\nAPI 액세스 승인\nACL 범위\nAPI 사용\nS/MIME 키 업로드\n사용자의 S/MIME 키 나열\n별칭의 S/MIME 키 가져오기\nS/MIME 키 삭제\n별칭의 기본 S/MIME 키 설정\nGmail S/MIME API는 Google Workspace 도메인의 사용자를 위한 S/MIME 이메일 인증서를 관리할 수 있는 프로그래매틱 액세스를 제공합니다.\n인증서가 작동하려면 관리자가 도메인에 S/MIME을 사용 설정 [https://support.google.com/a/answer/6374496?hl=ko]해야 합니다.\nS/MIME 표준 [https://en.wikipedia.org/wiki/S/MIME]은 공개 키 암호화 및 MIME 데이터 서명에 관한 사양을 제공합니다. 사용자 계정에서 S/MIME 인증서를 구성하면 Gmail에서 다음과 같은 방식으로 해당 인증서를 사용합니다.\nGmail은 사용자의 인증서와 비공개 키를 사용하여 발신 메일에 서명합니다.\nGmail은 사용자의 비공개 키를 사용하여 수신 메일을 복호화합니다.\nGmail은 수신자의 인증서와 공개 키를 사용하여 발신 메일을 암호화합니다.\nGmail은 발신자의 인증서와 공개 키를 사용하여 수신 메일을 확인합니다.\n개별 S/MIME 인증서를 생성하고 API를 사용하여 업로드합니다. 각 S/MIME 인증서는 사용자 이메일 계정의 특정 별칭에 해당합니다. 별칭에는 기본 이메일 주소와 맞춤 '다른 주소에서 메일 보내기' 주소가 포함됩니다. 단일 S/MIME 인증서가 각 별칭의 기본값으로 표시됩니다.\nAPI 액세스 승인", '/* Class to demonstrate the use of Gmail Insert Certificate from CSV File */\npublic class InsertCertFromCsv {\n  /**\n   * Upload S/MIME certificates based on the contents of a CSV file.\n   *\n   * <p>Each row of the CSV file should contain a user ID, path to the certificate, and the\n   * certificate password.\n   *\n   * @param csvFilename Name of the CSV file.\n   */\n  public static void insertCertFromCsv(String csvFilename) {\n    try {\n      File csvFile = new File(csvFilename);\n      CSVParser parser =\n          CSVParser.parse(csvFile, java.nio.charset.StandardCharsets.UTF_8, CSV ...
# [basic_langgraph_node] 생성된 답변: CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 다음과 같은 작업이 필요합니다:
#
# 1. **CSV 파일 준비**: CSV 파일에는 각 행에 사용자 ID, 인증서 경로, 인증서 비밀번호가 포함되어야 합니다. 예를 들어:
#    ```
#    user1@example.com,/path/to/user1_cert.p12,cert_password_1
#    user2@example.com,/path/to/user2_cert.p12,cert_password_2
#    user3@example.com,/path/to/user3_cert.p12,cert_password_3
#    ```
#
# 2. **CSV 파일 처리 함수 작성**: CSV 파일을 읽고 각 행의 정보를 사용하여 S/MIME 인증서를 업로드하는 함수를 작성합니다. Python에서는 `insert_cert_from_csv` 함수를 사용할 수 있습니다. 이 함수는 CSV 파일을 열고 각 행을 읽어 사용자 ID, 인증서 경로, 인증서 비밀번호를 추출합니다. 그런 다음 `create_smime_info`와 `insert_smime_info` 함수를 사용하여 인증서를 업로드합니다.
#
# 3. **인증서 업로드 및 기본값 설정**: 업로드된 인증서 중 만료일이 가장 늦은 인증서를 기본값으로 설정합니다. 기본 인증서가 만료되었거나 설정되지 않은 경우, 지정된 파일에서 인증서를 업로드하고 기본값으로 설정합니다.
#
# 이러한 작업을 통해 여러 사용자의 S/MIME 인증서를 효율적으로 관리할 수 있습니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?', 'answer': 'CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 다음과 같은 작업이 필요합니다:\n\n1. **CSV 파일 준비**: CSV 파일에는 각 행에 사용자 ID, 인증서 경로, 인증서 비밀번호가 포함되어야 합니다. 예를 들어:\n   ```\n   user1@example.com,/path/to/user1_cert.p12,cert_password_1\n   user2@example.com,/path/to/user2_cert.p12,cert_password_2\n   user3@example.com,/path/to/user3_cert.p12,cert_password_3\n   ```\n\n2. **CSV 파일 처리 함수 작성**: CSV 파일을 읽고 각 행의 정보를 사용하여 S/MIME 인증서를 업로드하는 함수를 작성합니다. Python에서는 `insert_cert_from_csv` 함수를 사용할 수 있습니다. 이 함수는 CSV 파일을 열고 각 행을 읽어 사용자 ID, 인증서 경로, 인증서 비밀번호를 추출합니다. 그런 다음 `create_smime_info`와 `insert_smime_info` 함수를 사용하여 인증서를 업로드합니다.\n\n3. **인증서 업로드 및 기본값 설정**: 업로드된 인증서 중 만료일이 가장 늦은 인증서를 기본값으로 설정합니다. 기본 인증서가 만료되었거나 설정되지 않은 경우, 지정된 파일에서 인증서를 업로드하고 기본값으로 설정합니다.\n\n이러한 작업을 통해 여러 사용자의 S/MIME 인증서를 효율적으로 관리할 수 있습니다.', 'rewritten': [{'role': 'user', 'content': 'CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?'}], 'queries': ['CSV 파일을 사용하여 S/MIME 인증서를 관리하는 방법은 무엇인가요?', 'How can I manage S/MIME certificates using a CSV file?'], 'search_results': ['except (OSError, IOError) as error:\n    print(f"An error occured while reading the CSV file: {error}")\n\n\nif __name__ == "__main__":\n  insert_cert_from_csv(csv_filename="xyz")\n인증서 관리\n이 예에서는 smimeInfo API의 여러 호출을 결합하여 조직의 인증서를 관리하는 방법을 보여줍니다. 사용자의 인증서를 나열하고 기본 인증서가 만료되었거나 설정되지 않은 경우 지정된 파일에서 찾은 인증서를 업로드합니다. 그런 다음 만료일이 가장 늦은 인증서를 기본값으로 설정합니다.\n그런 다음 이전 예와 같이 CSV 파일을 처리하는 함수에서 이를 호출합니다.\n--- 탭: 자바 ---\n.filepath {\n    color: #fff;\n    margin: 6px;\n    max-width: calc(100% - 160px); /* Give at least 160px for the "View on GitHub" button. */\n    text-overflow: ellipsis;\n    text-shadow: rgba(0,0,0,0.1) 1px 1px;\n    overflow: hidden;\n  }\n  .github-docwidget-gitinclude-code .prettyprint {\n    margin: 0;\n  }\n  .view-on-github {\n    text-shadow: rgba(12,12,12,0.1) 1px 1px;\n  }\n\n\n\n  \n  gmail/snippets/src/main/java/UpdateSmimeCerts.java\n  \n    \n    GitHub에서 보기 [https://github.com/googleworkspace/java-samples/blob/main/gmail/snippets/src/main/java/UpdateSmimeCerts.java]', '--- 탭: Python ---\n이전의 create_smime_info 및 insert_smime_info 호출을 사용하여 CSV 파일에 지정된 인증서를 업로드할 수 있습니다.\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n  \n  \n\n\n\n\n\n\n\n\n\n\n\n  .filepath {\n    color: #fff;\n    margin: 6px;\n    max-width: calc(100% - 160px); /* Give at least 160px for the "View on GitHub" button. */\n    text-overflow: ellipsis;\n    text-shadow: rgba(0,0,0,0.1) 1px 1px;\n    overflow: hidden;\n  }\n  .github-docwidget-gitinclude-code .prettyprint {\n    margin: 0;\n  }\n  .view-on-github {\n    text-shadow: rgba(12,12,12,0.1) 1px 1px;\n  }\n\n\n\n  \n  gmail/snippet/smime snippets/insert_cert_from_csv.py\n  \n    \n    GitHub에서 보기 [https://github.com/googleworkspace/python-samples/blob/main/gmail/snippet/smime%20snippets/insert_cert_from_csv.py]\n  \n  \n  \n\n  \n    \n  \n  \n  import csv\n\nimport create_smime_info\nimport insert_smime_info\n\n\ndef insert_cert_from_csv(csv_filename):\n  """Upload S/MIME certificates based on the contents of a CSV file.\n  Each row of the CSV file should contain a user ID, path to the certificate,\n  and the certificate password.\n\n  Args:\n    csv_filename: Name of the CSV file.\n  """', "이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\nS/MIME 인증서 관리\nbookmark_border\n이 페이지의 내용\nAPI 액세스 승인\nACL 범위\nAPI 사용\nS/MIME 키 업로드\n사용자의 S/MIME 키 나열\n별칭의 S/MIME 키 가져오기\nS/MIME 키 삭제\n별칭의 기본 S/MIME 키 설정\nGmail S/MIME API는 Google Workspace 도메인의 사용자를 위한 S/MIME 이메일 인증서를 관리할 수 있는 프로그래매틱 액세스를 제공합니다.\n인증서가 작동하려면 관리자가 도메인에 S/MIME을 사용 설정 [https://support.google.com/a/answer/6374496?hl=ko]해야 합니다.\nS/MIME 표준 [https://en.wikipedia.org/wiki/S/MIME]은 공개 키 암호화 및 MIME 데이터 서 ...
# run_langraph 호출 - 입력: 클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['클라우드 파이어스토어에서 부하 분산기를 어떻게 사용해야 하나요?', 'How should I use the load balancer in Cloud Firestore?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많은 스토리지 서버에 트래픽을 제공하는 작업을 분산하기 위해 자동으로 더 작은 조각으로 분할됩니다.
# QA 검색 결과: 길이 23개, 첫 문서: Q: Cloud Firestore의 부하 분산 기능은 어떻게 작동하나요?
# A: Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 확장되므로 부하 분
# [vector_search_tool] hybrid 검색 완료: '클라우드 파이어스토어에서 부하 분산기를 어떻게 사용해야 하나요?', tags=['firestore']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 15개, 첫 문서: Cloud Firestore는 비즈니스 요구사항을 충족하기 위해 자동 확장을 제공하는 고도로 분산된 시스템입니다. Cloud Firestore는 시스템에서 수신한 부하에 따라 데이
# QA 검색 결과: 길이 25개, 첫 문서: Q: Cloud Firestore Enterprise 버전에서 MongoDB 호환성을 갖춘 클라이언트를 사용하기 위한 연결 요구사항은 무엇인가요?
# A: MongoDB 호환성을 갖춘
# [vector_search_tool] hybrid 검색 완료: 'How should I use the load balancer in Cloud Firestore?', tags=['firestore']
# [tool_based_search_node] 실행 - state['search_results']=['Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많은 스토리지 서버에 트래픽을 제공하는 작업을 분산하기 위해 자동으로 더 작은 조각으로 분할됩니다. 초과 트래픽을 처리하기 위해 생성된 분할은 트래픽이 사라지더라도 약 24시간 동안 보관됩니다. 따라서 반복적으로 트래픽이 급증하면 분할이 유지되고 필요할 때마다 더 많은 분할이 도입됩니다.  이러한 메커니즘은 트래픽 부하 또는 데이터베이스 크기가 증가하면 Cloud Firestore 데이터베이스가 자동 확장되는 데 도움이 됩니다. 하지만 아래에 설명된 대로 주의해야 할 몇 가지 제한사항이 있습니다.\n\n스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Cloud Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데이터를 분할하거나 복제하도록 데이터 모델을 수정해야 합니다.', 'Cloud Firestore는 비즈니스 요구사항을 충족하기 위해 자동 확장을 제공하는 고도로 분산된 시스템입니다. Cloud Firestore는 시스템에서 수신한 부하에 따라 데이터를 동적으로 분할하고 결합합니다.\n\n부하 기반 분할은 사전 구성 없이 자동으로 이루어집니다. Cloud Firestore 부하 기반 분할 시스템에는 데이터를 모델링할 때 유의해야 하는 다른 문서 데이터베이스와 비교되는 중요한 고유한 특징이 있습니다.\n\nCloud Firestore의 분산된 특성으로 인해 일부 설계 옵션을 변경해야 할 수 있습니다. 특히 기본 복제본이 쓰기 처리량의 병목 현상인 데이터베이스에 최적화된 워크로드의 경우 더욱 그렇습니다.\n\n권장사항\n\n단일 스레드 클라이언트에서 대량의 데이터를 처리하는 워크로드는 병목 현상을 일으킬 수 있습니다. 클라이언트와 서버의 처리량이 유사하게 일치하므로 클라이언트가 단일 스레딩을 사용하여 데이터를 일괄 로드할 수 있습니다.\nCloud Firestore 데이터베이스는 훨씬 더 많은 동시 로드를 처리할 수 있지만 클라이언트가 요청을 동시에 전송하도록 구성해야 합니다.\n\nmongoimport\n\nmongoimport 도구를 사용하면 기본적으로 요청이 순차적으로 이루어집니다.\nCloud Firestore로의 로드 시간을 개선하려면 --numInsertionWorkers 플래그를 사용하여 작업자 수를 설정하세요.\n올바른 설정은 클라이언트 크기에 따라 조정해야 할 수 있지만 일반적으로 최소 32로 시작하는 것이 좋습니다.\n\n비동기 프로그래밍\n\nMongoDB 호환 API를 사용하여 자체 소프트웨어를 개발할 때 다음과 같은 방법으로 동시 로드를 개선할 수 있습니다.\n\n비동기 프레임워크: 비동기 프레임워크를 사용하면 요청을 동시에 처리하고 응답할 수 있습니다. 데이터베이스를 호출할 때 복잡한 풀링이나 큐를 개발할 필요가 없습니다.\n각 요청 흐름은 독립적인 연결을 사용하고 데이터베이스 동시에 호출할 수 있습니다.\n병렬 컴퓨팅 제품 사용: Cloud Run과 같은 서비스를 사용하면 시스템에서 데이터를 처리하는 데 필요한 컴퓨팅 작업자 수를 확장할 수 있습니다.\n\n일시적인 실패\n\nCloud Firestore와 같은 대규모 분산 시스템으로 작업할 때는 네트워크 일시적 오류나 문서의 경합과 같은 일시적인 오류가 발생할 수 있습니다.', 'require "google/cloud/firestore"\n\nfirestore = Google::Cloud::Firestore.new project_id: project_id\n\nshards_ref = firestore.col_group collection_path\n\ncount = 0\nshards_ref.get do |doc_ref|\ncount += doc_ref[:count]\nend\n\nputs "Count value is #{count}."distributed_counters.rb [https://github.com/googleapis/google-cloud-ruby/blob/0539c9e4faccfe857c5cd0999d9f50f1a4404531/google-cloud-firestore/samples/distributed_counters.rb#L60-L74]\n\n제한사항\n\n위 솔루션은 Cloud Firestore에서 공유 카운터를 만드는 확장 가능한 방법이지만 다음과 같은 제한사항에 유의해야 합니다.\n\n샤드 수 - 샤드 수는 분산 카운터의 성능을 좌우합니다. 샤드가 너무 적으면 일부 트랜잭션을 재시도해야 하므로 쓰기 작업이 느려집니다. 샤드가 너무 많으면 읽기가 느려지고 비용이 증가합니다.  더 느린 주기로 업데이트되는 개별 롤업 문서에서 카운터 합계를 유지하고 클라이언트가 이 문서를 읽어 합계를 가져오도록 하면 읽기 비용을 상쇄할 수 있습니다. 하지만 이 경우 클라이언트가 업데이트 직후 모든 샤드를 읽어 합계를 계산하지 않고 롤업 문서가 업데이트될 때까지 기다려야 한다는 단점이 있습니다.\n비용 - 카운터 값을 읽을 때 전체 샤드 하위 컬렉션이 로드되어야 하므로 샤드 수에 따라 비용이 선형으로 증가합니다.\n\n의견 보내기', '스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데이터를 분할하거나 복제하도록 데이터 모델을 수정해야 합니다.', '순차적으로 색인이 지정된 필드의 쓰기 속도 제한은 Cloud Firestore에서 색인 값을 저장하고 색인 쓰기를 조정하는 방법에 좌우됩니다. Cloud Firestore는 색인 쓰기별로 문서 이름과 각 색인이 지정된 필드의 값을 연결하는 키-값 항목을 정의합니다. Cloud Firestore는 이러한 색인 항목을 태블릿이라는 데이터 그룹으로 정리합니다. Cloud Firestore 서버마다 태블릿이 한 개 이상 있습니다. 특정 태블릿에 대한 쓰기 부하가 너무 높아지면 Cloud Firestore는 태블릿을 더 작은 태블릿으로 분할하고 서로 다른 Cloud Firestore 서버에 새 태블릿을 분산하여 수평으로 확장합니다.\n\nCloud Firestore는 사전순으로 가까운 색인 항목을 동일한 태블릿에 배치합니다. t ...
# [basic_langgraph_node] 생성된 답변: Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 확장되므로 별도의 부하 분산기를 실행할 필요가 없습니다. Firestore는 부하 기반 분할 시스템을 통해 시스템에서 수신한 부하에 따라 데이터를 동적으로 분할하고 결합하여 부하를 관리합니다. 따라서 사용자는 부하 분산기를 직접 설정하거나 관리할 필요 없이 Firestore의 자동 확장 기능을 활용할 수 있습니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': '클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?', 'answer': 'Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 확장되므로 별도의 부하 분산기를 실행할 필요가 없습니다. Firestore는 부하 기반 분할 시스템을 통해 시스템에서 수신한 부하에 따라 데이터를 동적으로 분할하고 결합하여 부하를 관리합니다. 따라서 사용자는 부하 분산기를 직접 설정하거나 관리할 필요 없이 Firestore의 자동 확장 기능을 활용할 수 있습니다.', 'rewritten': [{'role': 'user', 'content': '클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?'}], 'queries': ['클라우드 파이어스토어에서 부하 분산기를 어떻게 사용해야 하나요?', 'How should I use the load balancer in Cloud Firestore?'], 'search_results': ['Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많은 스토리지 서버에 트래픽을 제공하는 작업을 분산하기 위해 자동으로 더 작은 조각으로 분할됩니다. 초과 트래픽을 처리하기 위해 생성된 분할은 트래픽이 사라지더라도 약 24시간 동안 보관됩니다. 따라서 반복적으로 트래픽이 급증하면 분할이 유지되고 필요할 때마다 더 많은 분할이 도입됩니다.  이러한 메커니즘은 트래픽 부하 또는 데이터베이스 크기가 증가하면 Cloud Firestore 데이터베이스가 자동 확장되는 데 도움이 됩니다. 하지만 아래에 설명된 대로 주의해야 할 몇 가지 제한사항이 있습니다.\n\n스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Cloud Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데이터를 분할하거나 복제하도록 데이터 모델을 수정해야 합니다.', 'Cloud Firestore는 비즈니스 요구사항을 충족하기 위해 자동 확장을 제공하는 고도로 분산된 시스템입니다. Cloud Firestore는 시스템에서 수신한 부하에 따라 데이터를 동적으로 분할하고 결합합니다.\n\n부하 기반 분할은 사전 구성 없이 자동으로 이루어집니다. Cloud Firestore 부하 기반 분할 시스템에는 데이터를 모델링할 때 유의해야 하는 다른 문서 데이터베이스와 비교되는 중요한 고유한 특징이 있습니다.\n\nCloud Firestore의 분산된 특성으로 인해 일부 설계 옵션을 변경해야 할 수 있습니다. 특히 기본 복제본이 쓰기 처리량의 병목 현상인 데이터베이스에 최적화된 워크로드의 경우 더욱 그렇습니다.\n\n권장사항\n\n단일 스레드 클라이언트에서 대량의 데이터를 처리하는 워크로드는 병목 현상을 일으킬 수 있습니다. 클라이언트와 서버의 처리량이 유사하게 일치하므로 클라이언트가 단일 스레딩을 사용하여 데이터를 일괄 로드할 수 있습니다.\nCloud Firestore 데이터베이스는 훨씬 더 많은 동시 로드를 처리할 수 있지만 클라이언트가 요청을 동시에 전송하도록 구성해야 합니다.\n\nmongoimport\n\nmongoimport 도구를 사용하면 기본적으로 요청이 순차적으로 이루어집니다.\nCloud Firestore로의 로드 시간을 개선하려면 --numInsertionWorkers 플래그를 사용하여 작업자 수를 설정하세요.\n올바른 설정은 클라이언트 크기에 따라 조정해야 할 수 있지만 일반적으로 최소 32로 시작하는 것이 좋습니다.\n\n비동기 프로그래밍\n\nMongoDB 호환 API를 사용하여 자체 소프트웨어를 개발할 때 다음과 같은 방법으로 동시 로드를 개선할 수 있습니다.\n\n비동기 프레임워크: 비동기 프레임워크를 사용하면 요청을 동시에 처리하고 응답할 수 있습니다. 데이터베이스를 호출할 때 복잡한 풀링이나 큐를 개발할 필요가 없습니다.\n각 요청 흐름은 독립적인 연결을 사용하고 데이터베이스 동시에 호출할 수 있습니다.\n병렬 컴퓨팅 제품 사용: Cloud Run과 같은 서비스를 사용하면 시스템에서 데이터를 처리하는 데 필요한 컴퓨팅 작업자 수를 확장할 수 있습니다.\n\n일시적인 실패\n\nCloud Firestore와 같은 대규모 분산 시스템으로 작업할 때는 네트워크 일시적 오류나 문서의 경합과 같은 일시적인 오류가 발생할 수 있습니다.', 'require "google/cloud/firestore"\n\nfirestore = Google::Cloud::Firestore.new project_id: project_id\n\nshards_ref = firestore.col_group collection_path\n\ncount = 0\nshards_ref.get do |doc_ref|\ncount += doc_ref[:count]\nend\n\nputs "Count value is #{count}."distributed_counters.rb [https://github.com/googleapis/google-cloud-ruby/blob/0539c9e4faccfe857c5cd0999d9f50f1a4404531/google-cloud-firestore/samples/distributed_counters.rb#L60-L74]\n\n제한사항\n\n위 솔루션은 Cloud Firestore에서 공유 카운터를 만드는 확장 가능한 방법이지만 다음과 같은 제한사항에 유의해야 합니다.\n\n샤드 수 - 샤드 수는 분산 카운터의 성능을 좌우합니다. 샤드가 너무 적으면 일부 트랜잭션을 재시도해야 하므로 쓰기 작업이 느려집니다. 샤드가 너무 많으면 읽기가 느려지고 비용이 증가합니다.  더 느린 주기로 업데이트되는 개별 롤업 문서에서 카운터 합계를 유지하고 클라이언트가 이 문서를 읽어 합계를 가져오도록 하면 읽기 비용을 상쇄할 수 있습니다. 하지만 이 경우 클라이언트가 업데이트 직후 모든 샤드를 읽어 합계를 계산하지 않고 롤업 문서가 업데이트될 때까지 기다려야 한다는 단점이 있습니다.\n비용 - 카운터 값을 읽을 때 전체 샤드 하위 컬렉션이 로드되어야 하므로 샤드 수에 따라 비용이 선형으로 증가합니다.\n\n의견 보내기', '스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데 ...
# run_langraph 호출 - 입력: 범위 많으면 동의 어렵나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# 답변 불가 노드 시작
# 그래프 실행 결과: {'question': '범위 많으면 동의 어렵나요?', 'answer': '"(범위가 많으면 동의가 어려운지)"는 제가 모르는 내용입니다. 일상 질문 혹은 구글 API 관련 질문만 답변드릴 수 있어요.', 'rewritten': [{'role': 'user', 'content': '클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?'}], 'queries': ['클라우드 파이어스토어에서 부하 분산기를 어떻게 사용해야 하나요?', 'How should I use the load balancer in Cloud Firestore?'], 'search_results': ['Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많은 스토리지 서버에 트래픽을 제공하는 작업을 분산하기 위해 자동으로 더 작은 조각으로 분할됩니다. 초과 트래픽을 처리하기 위해 생성된 분할은 트래픽이 사라지더라도 약 24시간 동안 보관됩니다. 따라서 반복적으로 트래픽이 급증하면 분할이 유지되고 필요할 때마다 더 많은 분할이 도입됩니다.  이러한 메커니즘은 트래픽 부하 또는 데이터베이스 크기가 증가하면 Cloud Firestore 데이터베이스가 자동 확장되는 데 도움이 됩니다. 하지만 아래에 설명된 대로 주의해야 할 몇 가지 제한사항이 있습니다.\n\n스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Cloud Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데이터를 분할하거나 복제하도록 데이터 모델을 수정해야 합니다.', 'Cloud Firestore는 비즈니스 요구사항을 충족하기 위해 자동 확장을 제공하는 고도로 분산된 시스템입니다. Cloud Firestore는 시스템에서 수신한 부하에 따라 데이터를 동적으로 분할하고 결합합니다.\n\n부하 기반 분할은 사전 구성 없이 자동으로 이루어집니다. Cloud Firestore 부하 기반 분할 시스템에는 데이터를 모델링할 때 유의해야 하는 다른 문서 데이터베이스와 비교되는 중요한 고유한 특징이 있습니다.\n\nCloud Firestore의 분산된 특성으로 인해 일부 설계 옵션을 변경해야 할 수 있습니다. 특히 기본 복제본이 쓰기 처리량의 병목 현상인 데이터베이스에 최적화된 워크로드의 경우 더욱 그렇습니다.\n\n권장사항\n\n단일 스레드 클라이언트에서 대량의 데이터를 처리하는 워크로드는 병목 현상을 일으킬 수 있습니다. 클라이언트와 서버의 처리량이 유사하게 일치하므로 클라이언트가 단일 스레딩을 사용하여 데이터를 일괄 로드할 수 있습니다.\nCloud Firestore 데이터베이스는 훨씬 더 많은 동시 로드를 처리할 수 있지만 클라이언트가 요청을 동시에 전송하도록 구성해야 합니다.\n\nmongoimport\n\nmongoimport 도구를 사용하면 기본적으로 요청이 순차적으로 이루어집니다.\nCloud Firestore로의 로드 시간을 개선하려면 --numInsertionWorkers 플래그를 사용하여 작업자 수를 설정하세요.\n올바른 설정은 클라이언트 크기에 따라 조정해야 할 수 있지만 일반적으로 최소 32로 시작하는 것이 좋습니다.\n\n비동기 프로그래밍\n\nMongoDB 호환 API를 사용하여 자체 소프트웨어를 개발할 때 다음과 같은 방법으로 동시 로드를 개선할 수 있습니다.\n\n비동기 프레임워크: 비동기 프레임워크를 사용하면 요청을 동시에 처리하고 응답할 수 있습니다. 데이터베이스를 호출할 때 복잡한 풀링이나 큐를 개발할 필요가 없습니다.\n각 요청 흐름은 독립적인 연결을 사용하고 데이터베이스 동시에 호출할 수 있습니다.\n병렬 컴퓨팅 제품 사용: Cloud Run과 같은 서비스를 사용하면 시스템에서 데이터를 처리하는 데 필요한 컴퓨팅 작업자 수를 확장할 수 있습니다.\n\n일시적인 실패\n\nCloud Firestore와 같은 대규모 분산 시스템으로 작업할 때는 네트워크 일시적 오류나 문서의 경합과 같은 일시적인 오류가 발생할 수 있습니다.', 'require "google/cloud/firestore"\n\nfirestore = Google::Cloud::Firestore.new project_id: project_id\n\nshards_ref = firestore.col_group collection_path\n\ncount = 0\nshards_ref.get do |doc_ref|\ncount += doc_ref[:count]\nend\n\nputs "Count value is #{count}."distributed_counters.rb [https://github.com/googleapis/google-cloud-ruby/blob/0539c9e4faccfe857c5cd0999d9f50f1a4404531/google-cloud-firestore/samples/distributed_counters.rb#L60-L74]\n\n제한사항\n\n위 솔루션은 Cloud Firestore에서 공유 카운터를 만드는 확장 가능한 방법이지만 다음과 같은 제한사항에 유의해야 합니다.\n\n샤드 수 - 샤드 수는 분산 카운터의 성능을 좌우합니다. 샤드가 너무 적으면 일부 트랜잭션을 재시도해야 하므로 쓰기 작업이 느려집니다. 샤드가 너무 많으면 읽기가 느려지고 비용이 증가합니다.  더 느린 주기로 업데이트되는 개별 롤업 문서에서 카운터 합계를 유지하고 클라이언트가 이 문서를 읽어 합계를 가져오도록 하면 읽기 비용을 상쇄할 수 있습니다. 하지만 이 경우 클라이언트가 업데이트 직후 모든 샤드를 읽어 합계를 계산하지 않고 롤업 문서가 업데이트될 때까지 기다려야 한다는 단점이 있습니다.\n비용 - 카운터 값을 읽을 때 전체 샤드 하위 컬렉션이 로드되어야 하므로 샤드 수에 따라 비용이 선형으로 증가합니다.\n\n의견 보내기', '스토리지와 부하를 분할하는 데 시간이 걸리는 데다가, 트래픽을 너무 빨리 늘리면 서비스가 조정되는 동안 지연 시간 증가 또는 기한 초과 오류(일반적으로 핫스팟이라고 함)가 발생할 수 있습니다. 그러므로 키 범위 전반에 작업을 분산하면서 초당 500개의 작업을 수행하는 데이터베이스의 컬렉션에서 트래픽을 늘리는 것이 좋습니다. 점진적으로 늘린 후에 5분마다 최대 50%씩 트래픽을 늘립니다. 이 프로세스를 500/50/5 규칙이라고 하며, 워크로드에 맞게 최적으로 확장되도록 데이터베이스를 배치합니다.\n핵심사항: 최적의 확장을 위해 500/50/5 규칙에 따라 트래픽을 늘려야 합니다.\n분할은 부하 증가에 따라 자동으로 생성되지만 Firestore에서는 전용 복제 스토리지 서버 집합을 사용하여 단일 문서를 제공할 때까지만 키 범위를 분할할 수 있습니다. 그 결과, 단일 문서에서 지속적으로 많은 양의 작업을 동시 실행하면 해당 문서에 핫스팟이 발생할 수 있습니다. 단일 문서에서 긴 지연 시간이 지속적으로 발생하는 경우 여러 문서에 걸쳐 데이터를 분할하거나 복제하도록 데이터 모델을 수정해야 합니다.', '순차적으로 색인이 지정된 필드의 쓰기 속도 제한은 Cloud Firestore에서 색인 값을 저장하고 색인 쓰기를 조정하는 방법에 좌우됩니다. Cloud Firestore는 색인 쓰기별로 문서 이름과 각 색인이 지정된 필드의 값을  ...
# run_langraph 호출 - 입력: As a beginner who is not familiar with Google APIs, could you please explain in detail how the Cloud Platform is affected when Google Cloud session control features are enabled, and what specific user actions or applications are impacted by these policies?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['Google Cloud 세션 제어 기능이 활성화되었을 때 Google Cloud Platform에 미치는 영향은 무엇인가요?', '이러한 정책에 의해 영향을 받는 특정 사용자 행동이나 애플리케이션은 무엇인가요?', 'What is the impact on the Google Cloud Platform when Google Cloud session control features are enabled?', 'What specific user actions or applications are affected by these policies?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 15개, 첫 문서: 또한 사용자 계정 또는 서비스 계정이 모든 클라이언트에서 보유할 수 있는 총 새로고침 토큰 수에 대한 더 큰 제한도 있습니다. 일반적인 사용자는 이 한도를 초과하지 않지만 구현을
# QA 검색 결과: 길이 20개, 첫 문서: Q: Google Cloud 세션 제어 기능이란 무엇이며, 어떤 영향을 미치나요?
# A: Google Cloud 세션 제어 기능을 사용하여 사용자가 GCP 리소스에 액세스하는 동안
# [vector_search_tool] hybrid 검색 완료: 'Google Cloud 세션 제어 기능이 활성화되었을 때 Google Cloud Platform에 미치는 영향은 무엇인가요?', tags=['google_identity']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: arn:aws:iam::AWS_ACCOUNT_ID:policy/POLICY_NAME
#
# 다음을 바꿉니다.
#
#
# AWS_ACCOUNT_ID: 연결의 AWS IAM 사용자 ID 번호
# PO
# QA 검색 결과: 길이 25개, 첫 문서: Q: tables.setIamPolicy 메서드를 사용하여 특정 리소스의 접근 제어 정책을 설정하는 방법은 무엇인가요?
# A: tables.setIamPolicy 메서드는 지정된 리
# [vector_search_tool] hybrid 검색 완료: '이러한 정책에 의해 영향을 받는 특정 사용자 행동이나 애플리케이션은 무엇인가요?', tags=['google_identity']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: --- 탭: bq [https://cloud.google.com/bigquery/docs/control-access-to-resources-iam?hl=ko#bq] ---
# In t
# QA 검색 결과: 길이 22개, 첫 문서: Q: Google Cloud 세션 제어 기능이란 무엇이며, 어떤 영향을 미치나요?
# A: Google Cloud 세션 제어 기능을 사용하여 사용자가 GCP 리소스에 액세스하는 동안
# [vector_search_tool] hybrid 검색 완료: 'What is the impact on the Google Cloud Platform when Google Cloud session control features are enabled?', tags=['google_identity']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 14개, 첫 문서: Comply with all terms of service and policies
# The use of Google API Services, which includes our imp
# QA 검색 결과: 길이 24개, 첫 문서: Q: tables.setIamPolicy 메서드를 사용하여 특정 리소스의 접근 제어 정책을 설정하는 방법은 무엇인가요?
# A: tables.setIamPolicy 메서드는 지정된 리
# [vector_search_tool] hybrid 검색 완료: 'What specific user actions or applications are affected by these policies?', tags=['google_identity']
# [tool_based_search_node] 실행 - state['search_results']=['또한 사용자 계정 또는 서비스 계정이 모든 클라이언트에서 보유할 수 있는 총 새로고침 토큰 수에 대한 더 큰 제한도 있습니다. 일반적인 사용자는 이 한도를 초과하지 않지만 구현을 테스트하는 데 사용되는 개발자 계정은 초과할 수 있습니다.\n여러 프로그램, 머신 또는 기기를 승인해야 하는 경우 Google 계정당 승인하는 클라이언트 수를 15개 또는 20개로 제한하는 것이 한 가지 해결 방법입니다. Google Workspace 관리자 [https://support.google.com/a/answer/172176?hl=ko]인 경우 관리 권한이 있는 사용자를 추가로 만들어 일부 클라이언트를 승인할 수 있습니다.\nGoogle Cloud Platform (GCP) 조직의 세션 관리 정책 처리\nGCP 조직의 관리자는 Google Cloud 세션 제어 기능 [https://support.google.com/a/answer/9368756?hl=ko]을 사용하여 사용자가 GCP 리소스에 액세스하는 동안 사용자의 재인증을 자주 요구할 수 있습니다. 이 정책은 Google Cloud Console, Google Cloud SDK [https://cloud.google.com/sdk/gcloud?hl=ko] (gcloud CLI라고도 함), Cloud Platform 범위가 필요한 서드 파티 OAuth 애플리케이션에 대한 액세스에 영향을 미칩니다. 사용자에게 세션 제어 정책이 적용되어 있는 경우 세션 기간이 만료되면 갱신 토큰이 취소된 경우와 마찬가지로 API 호출에 오류가 발생합니다. 호출이 오류 유형 invalid_grant로 실패합니다. error_subtype 필드를 사용하여 취소된 토큰과 세션 제어 정책으로 인한 실패 (예: "error_subtype": "invalid_rapt")를 구분할 수 있습니다. 세션 기간이 매우 제한적일 수 있으므로 (1시간~24시간) 인증 세션을 다시 시작하여 이 시나리오를 원활하게 처리해야 합니다.\n마찬가지로 서버 간 배포에 사용자 인증 정보를 사용하거나 사용을 장려해서는 안 됩니다. 사용자 사용자 인증 정보가 장기 실행 작업 또는 작업을 위해 서버에 배포되고 고객이 이러한 사용자에게 세션 제어 정책을 적용하는 경우 세션 기간이 만료될 때 사용자를 다시 인증할 방법이 없으므로 서버 애플리케이션이 실패합니다.', '--- 탭: bq [https://cloud.google.com/bigquery/docs/control-access-to-resources-iam?hl=ko#bq] ---\nIn the Google Cloud console, activate Cloud Shell.\n    Activate Cloud Shell [https://console.cloud.google.com/?cloudshell=true&hl=ko]\n    \n      At the bottom of the Google Cloud console, a\n      Cloud Shell [https://cloud.google.com/shell/docs/how-cloud-shell-works?hl=ko]\n      session starts and displays a command-line prompt. Cloud Shell is a shell environment\n      with the Google Cloud CLI\n      already installed and with values already set for\n      your current project. It can take a few seconds for the session to initialize.\n    \n    \n  \n\n\n\n\n\n\n\n\n\n\n테이블 또는 뷰에 대한 액세스 권한을 부여하려면 bq add-iam-policy-binding 명령어 [https://cloud.google.com/bigquery/docs/reference/bq-cli-reference?hl=ko#bq_add-iam-policy-binding]를 사용합니다.\n\nbq add-iam-policy-binding --member=MEMBER_TYPE:MEMBER --role=ROLE\n  --table=true RESOURCE\n\n다음을 바꿉니다.\n\n\nMEMBER_TYPE: 구성원 유형(예: user, group, serviceAccount, domain)\nMEMBER: 회원의 이메일 주소 또는 도메인 이름\nROLE: 구성원에게 부여할 역할\nRESOURCE: 정책을 업데이트하려는 테이블 또는 뷰의 이름', '--- 탭: bq [https://cloud.google.com/bigquery/docs/control-access-to-resources-iam?hl=ko#bq] ---\nIn the Google Cloud console, activate Cloud Shell.\n    Activate Cloud Shell [https://console.cloud.google.com/?cloudshell=true&hl=ko]\n    \n      At the bottom of the Google Cloud console, a\n      Cloud Shell [https://cloud.google.com/shell/docs/how-cloud-shell-works?hl=ko]\n      session starts and displays a command-line prompt. Cloud Shell is a shell environment\n      with the Google Cloud CLI\n      already installed and with values already set for\n      your current project. It can take a few seconds for the session to initialize.\n    \n    \n  \n\n\n\n\n\n\n\n\n\n\n기존 루틴 정보(액세스 제어 포함)를 JSON 파일에 기록하려면 bq get-iam-policy 명령어 [https://cloud.google.com/bigquery/docs/reference/bq-cli-reference?hl=ko#bq_get-iam-policy]를 사용합니다.\n\nbq get-iam-policy --routine PROJECT_ID:DATASET.ROUTINE > PATH_TO_FILE\n\n다음을 바꿉니다.', '--- 탭: bq [https://cloud.google.com/bigquery/docs/control-access-to-resources-iam?hl=ko#bq] ---\nIn the Google Cloud console, activate Cloud Shell.\n    Activate Cloud Shell [https://console.cloud.google.com/?cloudshell=true&hl=ko]\n    \n      At the bottom of the Google Cloud console, a\n      Cloud Shell [https://cloud.google.com/shell/docs/how-cloud-shell-works?hl=ko]\n      session starts and displays a command-line prompt. Cloud Shell is a shell environment\n      with the Google Cloud CLI\n      already installed and with values already set for\n      your current project. It can take a few seconds for the session to initialize.\n    \n    \n  \n\n\n\n\n\n\n\n\n\n\n기존 데이터 세트 정보(액세스 제어 포함)를 JSON 파일에 기록하려면 bq show 명령어 [https://cloud. ...
# [basic_langgraph_node] 생성된 답변: When Google Cloud session control features are enabled, they can require users to frequently re-authenticate while accessing Google Cloud Platform (GCP) resources. This policy impacts access to the Google Cloud Console, Google Cloud SDK (also known as gcloud CLI), and third-party OAuth applications that require Cloud Platform scopes.
#
# If a session control policy is applied, and the session duration expires, API calls will fail with an error type of `invalid_grant`. The `error_subtype` field can be used to distinguish between failures due to revoked tokens and those due to session control policies, such as `"error_subtype": "invalid_rapt"`.
#
# Specific user actions or applications impacted by these policies include:
#
# 1. **Google Cloud Console Access**: Users may need to re-authenticate more frequently when accessing the console.
# 2. **Google Cloud SDK (gcloud CLI)**: Users using the CLI for managing GCP resources may experience interruptions and need to re-authenticate.
# 3. **Third-party OAuth Applications**: Applications that require Cloud Platform scopes may face access issues if session control policies are in place.
#
# Additionally, if user credentials are deployed on servers for long-running tasks, and session control policies are applied, the server application may fail when the session expires, as there would be no way to re-authenticate the user. Therefore, it is advised not to use or encourage the use of user credentials for server-to-server deployments.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'As a beginner who is not familiar with Google APIs, could you please explain in detail how the Cloud Platform is affected when Google Cloud session control features are enabled, and what specific user actions or applications are impacted by these policies?', 'answer': 'When Google Cloud session control features are enabled, they can require users to frequently re-authenticate while accessing Google Cloud Platform (GCP) resources. This policy impacts access to the Google Cloud Console, Google Cloud SDK (also known as gcloud CLI), and third-party OAuth applications that require Cloud Platform scopes.\n\nIf a session control policy is applied, and the session duration expires, API calls will fail with an error type of `invalid_grant`. The `error_subtype` field can be used to distinguish between failures due to revoked tokens and those due to session control policies, such as `"error_subtype": "invalid_rapt"`.\n\nSpecific user actions or applications impacted by these policies include:\n\n1. **Google Cloud Console Access**: Users may need to re-authenticate more frequently when accessing the console.\n2. **Google Cloud SDK (gcloud CLI)**: Users using the CLI for managing GCP resources may experience interruptions and need to re-authenticate.\n3. **Third-party OAuth Applications**: Applications that require Cloud Platform scopes may face access issues if session control policies are in place.\n\nAdditionally, if user credentials are deployed on servers for long-running tasks, and session control policies are applied, the server application may fail when the session expires, as there would be no way to re-authenticate the user. Therefore, it is advised not to use or encourage the use of user credentials for server-to-server deployments.', 'rewritten': [{'role': 'user', 'content': 'As a beginner who is not familiar with Google APIs, could you please explain in detail how the Cloud Platform is affected when Google Cloud session control features are enabled, and what specific user actions or applications are impacted by these policies?'}], 'queries': ['Google Cloud 세션 제어 기능이 활성화되었을 때 Google Cloud Platform에 미치는 영향은 무엇인가요?', '이러한 정책에 의해 영향을 받는 특정 사용자 행동이나 애플리케이션은 무엇인가요?', 'What is the impact on the Google Cloud Platform when Google Cloud session control features are enabled?', 'What specific user actions or applications are affected by these policies?'], 'search_results': ['또한 사용자 계정 또는 서비스 계정이 모든 클라이언트에서 보유할 수 있는 총 새로고침 토큰 수에 대한 더 큰 제한도 있습니다. 일반적인 사용자는 이 한도를 초과하지 않지만 구현을 테스트하는 데 사용되는 개발자 계정은 초과할 수 있습니다.\n여러 프로그램, 머신 또는 기기를 승인해야 하는 경우 Google 계정당 승인하는 클라이언트 수를 15개 또는 20개로 제한하는 것이 한 가지 해결 방법입니다. Google Workspace 관리자 [https://support.google.com/a/answer/172176?hl=ko]인 경우 관리 권한이 있는 사용자를 추가로 만들어 일부 클라이언트를 승인할 수 있습니다.\nGoogle Cloud Platform (GCP) 조직의 세션 관리 정책 처리\nGCP 조직의 관리자는 Google Cloud 세션 제어 기능 [https://support.google.com/a/answer/9368756?hl=ko]을 사용하여 사용자가 GCP 리소스에 액세스하는 동안 사용자의 재인증을 자주 요구할 수 있습니다. 이 정책은 Google Cloud Console, Google Cloud SDK [https://cloud.google.com/sdk/gcloud?hl=ko] (gcloud CLI라고도 함), Cloud Platform 범위가 필요한 서드 파티 OAuth 애플리케이션에 대한 액세스에 영향을 미칩니다. 사용자에게 세션 제어 정책이 적용되어 있는 경우 세션 기간이 만료되면 갱신 토큰이 취소된 경우와 마찬가지로 API 호출에 오류가 발생합니다. 호출이 오류 유형 invalid_grant로 실패합니다. error_subtype 필드를 사용하여 취소된 토큰과 세션 제어 정책으로 인한 실패 (예: "error_subtype": "invalid_rapt")를 구분할 수 있습니다. 세션 기간이 매우 제한적일 수 있으므로 (1시간~24시간) 인증 세션을 다시 시작하여 이 시나리오를 원활하게 처리해야 합니다.\n마찬가지로 서버 간 배포에 사용자 인증 정보를 사용하거나 사용을 장려해서는 안 됩니다. 사용자 사용자 인증 정보가 장기 실행 작업 또는 작업을 위해 서버에 배포되고 고객이 이러한 사용자에게 세션 제어 정책을 적용하는 경우 세션 기간이 만료될 때 사용자를 다시 인증할 방법이 없으므로 서버 애플리케이션이 실패합니다.', '--- 탭: bq [https://cloud.google.com/bigquery/docs/control-access-to-resources-iam?hl=ko#bq] ---\nIn the Google Cloud console, activate Cloud Shell.\n    Activate Cloud Shell [https://console.cloud.google.com/?cloudshell=true&hl=ko]\n    \n      At the bottom of the Google Cloud console, a\n      Cloud Shell [https://cloud.google.com/shell/docs/how-cloud-shell-works?hl=ko]\n      session starts and display ...
# run_langraph 호출 - 입력: firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Firestore에서 문서 바뀔 때마다 자동으로 뭔가 실행되게 하려면 firebase_functions에서 뭘 써야 되고, 예시 코드도 보여줄 수 있나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['Cloud Firestore에서 문서가 변경될 때 자동으로 실행되도록 Firebase Functions를 사용하는 방법과 예시 코드를 보여줄 수 있나요?', 'How can I use Firebase Functions to automatically execute something when a document changes in Cloud Firestore, and can you provide example code?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 23개, 첫 문서: Cloud Functions로 Firestore 확장
#
# bookmark_borderbookmark
#
# 컬렉션을 사용해 정리하기
#
# 내 환경설정을 기준으로 콘텐츠를 저장하고 분류하세요.
# QA 검색 결과: 길이 42개, 첫 문서: Q: Node.js에서 Cloud Firestore의 문서가 업데이트될 때 실행되는 함수를 정의하는 방법은 무엇인가요?
# A: 다음은 사용자가 프로필을 변경하면 실행되는 함수의 예시
# [vector_search_tool] hybrid 검색 완료: 'Cloud Firestore에서 문서가 변경될 때 자동으로 실행되도록 Firebase Functions를 사용하는 방법과 예시 코드를 보여줄 수 있나요?', tags=['firestore', 'firebase_authentication']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 24개, 첫 문서: 문서의 모든 변경사항에 대해 함수 트리거
#
# 실행되는 이벤트 유형에 관계없이 Cloud Firestore 문서의 모든 변경사항을 리슨하려면 '작성된 문서' 이벤트 트리거를 사용합니다
# QA 검색 결과: 길이 45개, 첫 문서: Q: Node.js에서 Cloud Firestore의 문서가 업데이트될 때 실행되는 함수를 정의하는 방법은 무엇인가요?
# A: 다음은 사용자가 프로필을 변경하면 실행되는 함수의 예시
# [vector_search_tool] hybrid 검색 완료: 'How can I use Firebase Functions to automatically execute something when a document changes in Cloud Firestore, and can you provide example code?', tags=['firestore', 'firebase_authentication']
# [tool_based_search_node] 실행 - state['search_results']=['Cloud Functions로 Firestore 확장\n\nbookmark_borderbookmark\n\n컬렉션을 사용해 정리하기\n\n내 환경설정을 기준으로 콘텐츠를 저장하고 분류하세요.\n\nCloud Functions를 사용하면 Firestore 데이터베이스를 변경하여 트리거되는 이벤트를 처리하는 Node.js 코드를 배포할 수 있습니다. 덕분에 자체 서버를 실행하지 않고도 앱에 서버 측 기능을 쉽게 추가할 수 있습니다.\n참고: 이 페이지의 예시는 Firebase용 Cloud Functions [https://firebase.google.com/docs/functions/?hl=ko]를 사용하며 Google Cloud용 Cloud Functions와 약간 다릅니다 [https://cloud.google.com/functions/docs/concepts/functions-and-firebase?hl=ko].\n사용 사례의 예시를 보려면 Cloud Functions로 무엇을 할 수 있나요? [https://firebase.google.com/docs/functions/use-cases?hl=ko] 또는 함수 샘플 [https://github.com/firebase/functions-samples] GitHub 저장소를 참조하세요.\n\nFirestore 함수 트리거\n\nFirebase용 Cloud Functions SDK는 특정 Firestore 이벤트에 연결된 핸들러를 만들 수 있는 functions.firestore [https://firebase.google.com/docs/reference/functions/firebase-functions.firestore?hl=ko] 객체를 내보냅니다.', '문서의 모든 변경사항에 대해 함수 트리거\n\n실행되는 이벤트 유형에 관계없이 Cloud Firestore 문서의 모든 변경사항을 리슨하려면 \'작성된 문서\' 이벤트 트리거를 사용합니다. 다음은 사용자가 생성, 업데이트 또는 삭제될 때 실행되는 함수의 예시입니다.\n\nNode.jsconst {\nonDocumentWritten,\nChange,\nFirestoreEvent\n} = require(\'firebase-functions/v2/firestore\');\n\nexports.modifyuser = onDocumentWritten("users/{userId}", (event) => {\n// Get an object with the current document values.\n// If the document does not exist, it was deleted\nconst document =  event.data.after.data();\n\n// Get an object with the previous document values\nconst previousValues =  event.data.before.data();\n\n// perform more operations ...\n});\n\n추가 인증 정보의 경우 onDocumentWrittenWithAuthContext를 사용하세요.\nPythonfrom firebase_functions.firestore_fn import (\non_document_written,\nEvent,\nChange,\nDocumentSnapshot,\n)\n\n@on_document_written(document="users/{userId}")\ndef myfunction(event: Event[Change[DocumentSnapshot | None]]) -> None:\n# Get an object with the current document values.\n# If the document does not exist, it was deleted.\ndocument = (event.data.after.to_dict()\nif event.data.after is not None else None)', 'Cloud Firestore 함수 트리거\n\nCloud Functions for Firebase SDK는 특정 Cloud Firestore 이벤트에 연결된 핸들러를 생성할 수 있도록 다음 Cloud Firestore 이벤트 트리거를 내보냅니다.\n\nNode.js|  |  |\n| --- | --- |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\nPython|  |  |\n| --- | --- |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n|  |  |\n\nCloud Firestore 이벤트는 문서 변경 시에만 트리거됩니다. 데이터가 변경되지 않는 Cloud Firestore 문서를 업데이트(노옵스(no-ops) 쓰기)할 때에는 업데이트 또는 쓰기 이벤트가 생성되지 않습니다. 특정 필드에 이벤트를 추가할 수 없습니다.\n\nCloud Functions for Firebase가 사용 설정된 프로젝트가 없으면 Cloud Functions for Firebase(2세대) 시작하기 [https://firebase.google.com/docs/functions/beta/get-started?hl=ko]를 읽고 Cloud Functions for Firebase 프로젝트를 구성 및 설정하세요.\n\nCloud Firestore 트리거 함수 작성\n\n함수 트리거 정의\n\nCloud Firestore 트리거를 정의하려면 문서 경로와 이벤트 유형을 지정합니다.\n\nNode.jsconst {\nonDocumentWritten,\nonDocumentCreated,\nonDocumentUpdated,\nonDocumentDeleted,\nChange,\nFirestoreEvent\n} = require(\'firebase-functions/v2/firestore\');\n\nexports.myfunction = onDocumentWritten("my-collection/{docId}", (event) => {\n/* ... */\n});\n\nPythonfrom firebase_functions.firestore_fn import (\non_document_created,\non_document_deleted,\non_document_updated,\non_document_written,\nEvent,\nChange,\nDocumentSnapshot,\n)', 'Source URL: https://cloud.google.com/firestore/docs/manage-data/add-data?hl=ko\nTitle: 데이터 추가 및 업데이트\n\n이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\n\n의견 보내기\n\n컬렉션을 사용해 정리하기\n\n내 환경설정을 기준으로 콘텐츠를 저장하고 분류하세요.\n\n데이터 추가 및 업데이트\n\n이 문서에서는 Firestore에서 개별 문서를 설정, 추가 또는 업데이트하는 방법을 설명합니다. 데이터를 일괄 쓰기하려면 트랜잭션 및 일괄 쓰기 [https://cloud.google.com/firestore/native/docs/manage-data/transactions?hl=ko]를 참고하세요.\n\n개요\n\n다음 방법 중 하나로 Firestore에 데이터를 쓸 수 있습니다.\n\n문서 식별자를 명시적으로 지정하여 컬렉션 내의 문서 데이터를 설정합니다.\n컬렉션에 새 문서를 추가합니다. 이 경우 Firestore에서 자동으로 문서 식별자를 생성합니다.\n자동으로 생성된 식별자로 빈 문서를 만들고 나중에 데이터를 할당합니다.\n\n참고: 코드 샘플에서는 여러 언어를 다루지만 샘플을 설명하는 텍스트는 웹 메서드 이름을 참조합니다.시작하기 전에\n\n데이터를 설정, 추가 또는 업데이트하도록 Fi ...
# [basic_langgraph_node] 생성된 답변: Cloud Firestore에서 문서가 변경될 때마다 자동으로 실행되는 함수를 작성하려면 `firebase-functions` 라이브러리를 사용하여 트리거를 설정할 수 있습니다. `onDocumentWritten` 함수는 문서가 생성, 업데이트 또는 삭제될 때 트리거됩니다. 아래는 Node.js와 Python에서 각각의 예시 코드입니다.
#
# ### Node.js 예시 코드
# ```javascript
# const {
#   onDocumentWritten,
#   Change,
#   FirestoreEvent
# } = require('firebase-functions/v2/firestore');
#
# exports.modifyuser = onDocumentWritten("users/{userId}", (event) => {
#   // 현재 문서의 값을 가져옵니다.
#   const document = event.data.after.data();
#
#   // 이전 문서의 값을 가져옵니다.
#   const previousValues = event.data.before.data();
#
#   // 추가 작업 수행 ...
# });
# ```
#
# ### Python 예시 코드
# ```python
# from firebase_functions.firestore_fn import (
#   on_document_written,
#   Event,
#   Change,
#   DocumentSnapshot,
# )
#
# @on_document_written(document="users/{userId}")
# def myfunction(event: Event[Change[DocumentSnapshot | None]]) -> None:
#   # 현재 문서의 값을 가져옵니다.
#   document = (event.data.after.to_dict()
#               if event.data.after is not None else None)
#
#   # 이전 문서의 값을 가져옵니다.
#   previous_values = (event.data.before.to_dict()
#                      if event.data.before is not None else None)
#
#   # 추가 작업 수행 ...
# ```
#
# 이 코드는 `users/{userId}` 경로의 문서가 생성, 업데이트 또는 삭제될 때마다 트리거됩니다. `event.data.after`는 현재 문서의 데이터를, `event.data.before`는 이전 문서의 데이터를 제공합니다. 이를 통해 문서의 변경 사항을 감지하고 필요한 작업을 수행할 수 있습니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Firestore에서 문서 바뀔 때마다 자동으로 뭔가 실행되게 하려면 firebase_functions에서 뭘 써야 되고, 예시 코드도 보여줄 수 있나요?', 'answer': 'Cloud Firestore에서 문서가 변경될 때마다 자동으로 실행되는 함수를 작성하려면 `firebase-functions` 라이브러리를 사용하여 트리거를 설정할 수 있습니다. `onDocumentWritten` 함수는 문서가 생성, 업데이트 또는 삭제될 때 트리거됩니다. 아래는 Node.js와 Python에서 각각의 예시 코드입니다.\n\n### Node.js 예시 코드\n```javascript\nconst {\n  onDocumentWritten,\n  Change,\n  FirestoreEvent\n} = require(\'firebase-functions/v2/firestore\');\n\nexports.modifyuser = onDocumentWritten("users/{userId}", (event) => {\n  // 현재 문서의 값을 가져옵니다.\n  const document = event.data.after.data();\n\n  // 이전 문서의 값을 가져옵니다.\n  const previousValues = event.data.before.data();\n\n  // 추가 작업 수행 ...\n});\n```\n\n### Python 예시 코드\n```python\nfrom firebase_functions.firestore_fn import (\n  on_document_written,\n  Event,\n  Change,\n  DocumentSnapshot,\n)\n\n@on_document_written(document="users/{userId}")\ndef myfunction(event: Event[Change[DocumentSnapshot | None]]) -> None:\n  # 현재 문서의 값을 가져옵니다.\n  document = (event.data.after.to_dict()\n              if event.data.after is not None else None)\n\n  # 이전 문서의 값을 가져옵니다.\n  previous_values = (event.data.before.to_dict()\n                     if event.data.before is not None else None)\n\n  # 추가 작업 수행 ...\n```\n\n이 코드는 `users/{userId}` 경로의 문서가 생성, 업데이트 또는 삭제될 때마다 트리거됩니다. `event.data.after`는 현재 문서의 데이터를, `event.data.before`는 이전 문서의 데이터를 제공합니다. 이를 통해 문서의 변경 사항을 감지하고 필요한 작업을 수행할 수 있습니다.', 'rewritten': [{'role': 'user', 'content': 'firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Firestore에서 문서 바뀔 때마다 자동으로 뭔가 실행되게 하려면 firebase_functions에서 뭘 써야 되고, 예시 코드도 보여줄 수 있나요?'}], 'queries': ['Cloud Firestore에서 문서가 변경될 때 자동으로 실행되도록 Firebase Functions를 사용하는 방법과 예시 코드를 보여줄 수 있나요?', 'How can I use Firebase Functions to automatically execute something when a document changes in Cloud Firestore, and can you provide example code?'], 'search_results': ['Cloud Functions로 Firestore 확장\n\nbookmark_borderbookmark\n\n컬렉션을 사용해 정리하기\n\n내 환경설정을 기준으로 콘텐츠를 저장하고 분류하세요.\n\nCloud Functions를 사용하면 Firestore 데이터베이스를 변경하여 트리거되는 이벤트를 처리하는 Node.js 코드를 배포할 수 있습니다. 덕분에 자체 서버를 실행하지 않고도 앱에 서버 측 기능을 쉽게 추가할 수 있습니다.\n참고: 이 페이지의 예시는 Firebase용 Cloud Functions [https://firebase.google.com/docs/functions/?hl=ko]를 사용하며 Google Cloud용 Cloud Functions와 약간 다릅니다 [https://cloud.google.com/functions/docs/concepts/functions-and-firebase?hl=ko].\n사용 사례의 예시를 보려면 Cloud Functions로 무엇을 할 수 있나요? [https://firebase.google.com/docs/functions/use-cases?hl=ko] 또는 함수 샘플 [https://github.com/firebase/functions-samples] GitHub 저장소를 참조하세요.\n\nFirestore 함수 트리거\n\nFirebase용 Cloud Functions SDK는 특정 Firestore 이벤트에 연결된 핸들러를 만들 수 있는 functions.firestore [https://firebase.google.com/docs/reference/functions/firebase-functions.firestore?hl=ko] 객체를 내보냅니다.', '문서의 모든 변경사항에 대해 함수 트리거\n\n실행되는 이벤트 유형에 관계없이 Cloud Firestore 문서의 모든 변경사항을 리슨하려면 \'작성된 문서\' 이벤트 트리거를 사용합니다. 다음은 사용자가 생성, 업데이트 또는 삭제될 때 실행되는 함수의 예시입니다.\n\nNode.jsconst {\nonDocumentWritten,\nChange,\nFirestoreEvent\n} = require(\'firebase-functions/v2/firestore\');\n\nexports.modifyuser = onDocumentWritten("users/{userId}", (event) => {\n// Get an object with the current document values.\n// If the document does not exist, it was deleted\nconst document =  event.data.after.data();\n\n// Get an object with the previous document values\nconst previousValues =  event.data.before.data();\n\n// perform more operations ...\n});\n\n추가 인증 정보의 경우 onDocumentWrittenWithAuthContext를 사용하세요.\nPythonfrom firebase_functions.firestore_fn import (\non_document_written,\nEvent,\nChange,\nDocumentSnapshot,\n)\n\n@on_document_written(document="users/{userId}")\ndef myfunction(event: Event[Change[DocumentSnapshot | None]]) -> None:\n# Get an object with the current document values.\n# If the document does not exist, it was deleted.\ndocument = (event.data.after.to_dict()\nif event.data.after is not None else None)', 'Cloud Firestore 함수 트리거\n\nCloud Functions for Firebase SDK는 특정 Cloud Firestore 이벤트에 연결된 핸들러를 생성할 ...
# run_langraph 호출 - 입력: Firebase에서 다단계 인증(MFA)을 사용할 때 Objective-C로 사용자 인증을 완료하는 방법과 관련된 코드 예시가 궁금합니다. 어떤 방식으로 인증 정보를 가져오고, Objective-C에서는 어떻게 구현하나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['Firebase에서 다단계 인증(MFA)을 사용할 때 Objective-C로 사용자 인증을 완료하는 방법과 관련된 코드 예시는 무엇인가요?', 'Objective-C에서 Firebase 다단계 인증(MFA) 정보를 가져오는 방법은 무엇인가요?', 'What is an example of code for completing user authentication using multi-factor authentication (MFA) in Firebase with Objective-C?', 'How do you retrieve authentication information for Firebase multi-factor authentication (MFA) in Objective-C?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 13개, 첫 문서: Firebase Authentication with Identity Platform으로 업그레이드했다면 웹 앱에 SMS 다중 인증(MFA)을 추가할 수 있습니다.
#
# 다중 인증(MF
# QA 검색 결과: 길이 24개, 첫 문서: Q: Objective-C에서 다중 인증(MFA) 사용자 로그인 처리를 위한 코드 예시는 어떻게 되나요?
# A: 다음은 Objective-C에서 다중 인증(MFA) 사용자 로그인 처
# [vector_search_tool] hybrid 검색 완료: 'Firebase에서 다단계 인증(MFA)을 사용할 때 Objective-C로 사용자 인증을 완료하는 방법과 관련된 코드 예시는 무엇인가요?', tags=['firebase_authentication']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: Firebase Authentication with Identity Platform으로 업그레이드했다면 시간 기반 일회용 비밀번호(TOTP) 다중 인증(MFA)을 앱에 추가할 수
# QA 검색 결과: 길이 22개, 첫 문서: Q: Firebase에서 다중 인증(MFA) 세션을 가져오는 방법은 무엇인가요?
# A: 다중 인증(MFA) 세션을 가져오려면 다음과 같이 코드를 작성합니다:
# ```javascript
# [vector_search_tool] hybrid 검색 완료: 'Objective-C에서 Firebase 다단계 인증(MFA) 정보를 가져오는 방법은 무엇인가요?', tags=['firebase_authentication']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: --- 탭: Objective-C [https://firebase.google.com/docs/auth/ios/google-signin?hl=ko#objective-c] ---
# [
# QA 검색 결과: 길이 23개, 첫 문서: Q: Objective-C에서 다중 인증(MFA) 사용자 로그인 처리를 위한 코드 예시는 어떻게 되나요?
# A: 다음은 Objective-C에서 다중 인증(MFA) 사용자 로그인 처
# ...
# [basic_langgraph_node] 생성된 답변: 'fileId'는 Google Drive API에서 파일의 고유 식별자를 의미합니다. 이는 특정 파일을 식별하고 해당 파일에 대한 작업을 수행하는 데 사용됩니다. 예를 들어, 파일의 메타데이터를 가져오거나, 파일을 업데이트하거나, 삭제하는 등의 작업을 수행할 때 'fileId'를 사용하여 해당 파일을 지정합니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'fileId는 무엇을 의미하나요?', 'answer': "'fileId'는 Google Drive API에서 파일의 고유 식별자를 의미합니다. 이는 특정 파일을 식별하고 해당 파일에 대한 작업을 수행하는 데 사용됩니다. 예를 들어, 파일의 메타데이터를 가져오거나, 파일을 업데이트하거나, 삭제하는 등의 작업을 수행할 때 'fileId'를 사용하여 해당 파일을 지정합니다.", 'rewritten': [{'role': 'user', 'content': 'fileId는 무엇을 의미하나요?'}], 'queries': ['fileId는 무엇을 의미하나요?', 'What does fileId mean?'], 'search_results': ['| Fields |\n| --- |\n| target_id | int32 The target ID that identifies the target on the stream. Must be a positive number and non-zero. If target_id is 0 (or unspecified), the server will assign an ID for this target and return that in a TargetChange::ADD event. Once a target with target_id=0 is added, all subsequent targets must also have target_id=0. If an AddTarget request with target_id != 0 is sent to the server after a target with target_id=0 is added, the server will immediately send a response with a TargetChange::Remove event. Note that if the client sends multiple AddTarget requests without an ID, the order of IDs returned in TargetChange.target_ids are undefined. Therefore, clients should provide a target ID instead of relying on the server to assign one. If target_id is non-zero, there must not be an existing active target on this stream with the same ID. |\n| once | bool If the target should be removed once it is current and consistent. |', '리소스: 변경\n파일 또는 공유 드라이브의 변경사항을 나타냅니다.\nJSON 표현\n{\n  "id": string,\n  "deleted": boolean,\n  "file": {\n    object (File)\n  },\n  "fileId": string,\n  "modificationDate": string,\n  "kind": string,\n  "type": string,\n  "teamDriveId": string,\n  "teamDrive": {\n    object (TeamDrive)\n  },\n  "changeType": string,\n  "selfLink": string,\n  "driveId": string,\n  "drive": {\n    object (Drive)\n  }\n}\n필드\nid\nstring (int64 format)\n변경의 ID입니다.\ndeleted\nboolean\n삭제 또는 액세스 권한 상실 등으로 인해 파일 또는 공유 드라이브가 이 변경사항 목록에서 삭제되었는지 여부입니다.\nfile\nobject (File)\n업데이트된 파일 상태입니다. 유형이 파일이고 이 변경사항 목록에서 파일이 삭제되지 않은 경우 표시됩니다.\nfileId\nstring\n이 변경사항과 연결된 파일의 ID입니다.\nmodificationDate\nstring\n이 수정사항이 적용된 시간입니다.\nkind\nstring\n항상 drive#change입니다.\ntype\n(deprecated)\nstring\n이 항목은 지원 중단되었습니다.\n지원 중단됨: 대신 changeType를 사용하세요.\nteamDriveId\n(deprecated)\nstring\n이 항목은 지원 중단되었습니다.\n지원 중단됨: 대신 driveId를 사용하세요.\nteamDrive\n(deprecated)\nobject (TeamDrive)\n이 항목은 지원 중단되었습니다.\n지원 중단됨: 대신 drive를 사용하세요.\nchangeType\nstring\n변경 유형입니다. 가능한 값은 file 및 drive입니다.\nselfLink\nstring\n이 변경사항으로 연결되는 링크입니다.\ndriveId\nstring\n이 변경사항과 연결된 공유 드라이브의 ID입니다.\ndrive\nobject (Drive)\n업데이트된 공유 드라이브 상태입니다. changeType이 drive인 경우, 사용자가 여전히 공유 드라이브의 멤버이고 공유 드라이브가 삭제되지 않은 경우 표시됩니다.\n메서드\nget', '경로 매개변수\n매개변수\nspreadsheetId\nstring\n메타데이터를 가져올 스프레드시트의 ID입니다.\n요청 본문\n요청 본문에는 다음과 같은 구조의 데이터가 포함됩니다.\nJSON 표현\n{\n  "dataFilters": [\n    {\n      object (DataFilter [https://developers.google.com/workspace/sheets/api/reference/rest/v4/DataFilter?hl=ko])\n    }\n  ]\n}\n필드\ndataFilters[]\nobject (DataFilter [https://developers.google.com/workspace/sheets/api/reference/rest/v4/DataFilter?hl=ko])\n반환할 DeveloperMetadata 항목을 결정하는 데 사용되는 기준을 설명하는 데이터 필터입니다. 지정된 필터와 일치하는 DeveloperMetadata가 응답에 포함됩니다.\n응답 본문\n개발자 메타데이터 검색 요청에 대한 답장입니다.\n성공한 경우 응답 본문은 다음과 같은 구조의 데이터를 포함합니다.\nJSON 표현\n{\n  "matchedDeveloperMetadata": [\n    {\n      object (MatchedDeveloperMetadata [https://developers.google.com/workspace/sheets/api/reference/rest/v4/spreadsheets.developerMetadata/search?hl=ko#MatchedDeveloperMetadata])\n    }\n  ]\n}\n필드\nmatchedDeveloperMetadata[]\nobject (MatchedDeveloperMetadata [https://developers.google.com/workspace/sheets/api/reference/rest/v4/spreadsheets.developerMetadata/search?hl=ko#MatchedDeveloperMetadata])\n검색 요청의 기준과 일치하는 메타데이터입니다.\n승인 범위\n다음 OAuth 범위 중 하나가 필요합니다.\nhttps://www.googleapis.com/auth/drive\nhttps://www.googleapis.com/auth/drive.file\nhttps://www.googleapis.com/auth/spreadsheets', 'shortcutDetails.targetId\nstring\n이 바로가기가 가리키는 파일의 ID입니다. files.create 요청에서만 설정할 수 있습니다.\nshortcutDetails.targetMimeType\nstring\n출력 전용입니다. 이 바로가기가 가리키는 파일의 MIME 유형입니다. 이 필드 ...
# run_langraph 호출 - 입력: Gmail 작업을 선언하는 방법에 대해 자세히 알고 싶은데, Declaring Actions 관련 자료는 어디서 찿을수 있나요?, 이미지: False
# analyze_image 호출됨 - 이미지 존재: False
# [tool_based_search_node] 실행 - queries=['Gmail 작업을 선언하는 방법과 Declaring Actions 관련 자료는 어디서 찾을 수 있나요?', 'How can I declare actions for Gmail and where can I find resources related to Declaring Actions?']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 15개, 첫 문서: Gmail 작업
# Gmail은 schema.org 마크업을 사용하여 사용자 작업을 가속화하고 사용자가 이메일에서 필요로 하는 가장 중요한 정보를 강조합니다.
# Gmail은 다음과 같은
# QA 검색 결과: 길이 22개, 첫 문서: Q: Gmail의 작업 선언 방법에 대한 자료는 어디에서 찾을 수 있나요?
# A: 작업 선언 방법에 대한 자세한 내용은 작업 선언(Declaring Actions) 문서를 참고하세요
# [vector_search_tool] hybrid 검색 완료: 'Gmail 작업을 선언하는 방법과 Declaring Actions 관련 자료는 어디서 찾을 수 있나요?', tags=['gmail']
# 원문 retriever 생성 완료
# QA retriever 생성 완료
# 원문 검색 결과: 길이 16개, 첫 문서: Source URL: https://developers.google.com/workspace/gmail/markup/actions/declaring-actions
#
# 이 페이지는 C
# QA 검색 결과: 길이 25개, 첫 문서: Q: Gmail의 작업 선언 방법에 대한 자료는 어디에서 찾을 수 있나요?
# A: 작업 선언 방법에 대한 자세한 내용은 작업 선언(Declaring Actions) 문서를 참고하세요
# [vector_search_tool] hybrid 검색 완료: 'How can I declare actions for Gmail and where can I find resources related to Declaring Actions?', tags=['gmail']
# [tool_based_search_node] 실행 - state['search_results']=['Gmail 작업\nGmail은 schema.org 마크업을 사용하여 사용자 작업을 가속화하고 사용자가 이메일에서 필요로 하는 가장 중요한 정보를 강조합니다.\nGmail은 다음과 같은 유형의 작업 및 대화형 카드를 지원합니다.\n클릭 한 번으로 실행할 수 있는 거의 모든 항목에 대한 원클릭 작업 [https://developers.google.com/workspace/gmail/markup/reference/one-click-action?hl=ko]\n더 복잡한 상호작용을 위한 Go-to Action [https://developers.google.com/workspace/gmail/markup/reference/go-to-action?hl=ko]\n항공편 양방향 카드 [https://developers.google.com/workspace/gmail/markup/reference/flight-reservation?hl=ko]\nGmail 하이라이트\nGmail은 동일한 schema.org 마크업을 사용하여 이메일 내에서 가장 중요한 정보를 강조 표시하고 사용자가 이에 따라 조치를 취할 수 있도록 합니다.\n버스 강조 표시 [https://developers.google.com/workspace/gmail/markup/reference/bus-reservation?hl=ko]\n렌터카 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/rental-car?hl=ko]\n항공편 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/flight-reservation?hl=ko]\n티켓이 있는 이벤트의 이벤트 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/event-reservation?hl=ko]\n주문 [https://developers.google.com/workspace/gmail/markup/reference/order?hl=ko] 및 소포 배송 [https://developers.google.com/workspace/gmail/markup/reference/parcel-delivery?hl=ko] 쇼핑 관련 주요 사항', 'Source URL: https://developers.google.com/workspace/gmail/markup/actions/handling-action-requests\n\n이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\n작업 요청 처리\nbookmark_border\n이 페이지의 내용\n1단계: 요청 확인\n2단계: 작업 처리\n3단계: 응답 코드 반환\n추가 자료\n작업 선언 [https://developers.google.com/workspace/gmail/markup/actions/declaring-actions?hl=ko]에 설명된 대로 사용자가 인앱 작업과 상호작용하면 Google은 작업에 선언된 URL로 HTTP 요청을 보냅니다.\n다음 예에서는 비용 보고서에 관한 이메일에 ConfirmAction 버튼을 추가합니다.\n--- 탭: JSON-LD ---\n<script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "EmailMessage",\n  "potentialAction": {\n    "@type": "ConfirmAction",\n    "name": "Approve Expense",\n    "handler": {\n      "@type": "HttpActionHandler",\n      "url": "https://myexpenses.com/approve?expenseId=abc123"\n    }\n  },\n  "description": "Approval request for John\'s $10.13 expense for office supplies"\n}\n</script>', 'Source URL: https://developers.google.com/workspace/gmail/markup/actions/declaring-actions\n\n이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\n작업 선언\nbookmark_border\n이 페이지의 내용\n바로가기 작업\n모바일 딥 링크\n인앱 액션 수\n만료되는 작업\n추가 자료\nschema.org의 작업은 구조화된 데이터에서 실행할 수 있는 동사 또는 활동을 나타냅니다. 여러 유형의 작업 [https://developers.google.com/workspace/gmail/markup/actions/actions-overview?hl=ko]이 지원되며 모두 유사한 구조화된 데이터로 정의할 수 있습니다.\n바로가기 작업\nschema.org 항목을 사용하여 콘텐츠에 마크업을 추가하는 경우 해당 항목에 이동 작업을 추가할 수 있습니다. 예를 들어 EmailMessage 항목에 ViewAction 바로가기 링크를 추가하려면 다음 예와 같이 이메일의 potentialAction 속성을 채웁니다.\n--- 탭: JSON-LD ---\n<script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "EmailMessage",\n  "potentialAction": {\n    "@type": "ViewAction",\n    "target": "https://watch-movies.com/watch?movieId=abc123",\n    "name": "Watch movie"\n  },\n  "description": "Watch the \'Avengers\' movie online"\n}\n</script>', '이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\n개요\nbookmark_border ...
# [basic_langgraph_node] 생성된 답변: Gmail 작업을 선언하는 방법에 대한 자세한 내용은 "작업 선언(Declaring Actions)" 문서를 참고하시면 됩니다. 해당 문서에서는 Gmail에서 작업을 어떻게 선언하고 사용할 수 있는지에 대한 정보를 제공합니다.
# [evaluate_answer_node] 평가 결과: good
# [evaluate_answer_node] 최종 : good
# 그래프 실행 결과: {'question': 'Gmail 작업을 선언하는 방법에 대해 자세히 알고 싶은데, Declaring Actions 관련 자료는 어디서 찿을수 있나요?', 'answer': 'Gmail 작업을 선언하는 방법에 대한 자세한 내용은 "작업 선언(Declaring Actions)" 문서를 참고하시면 됩니다. 해당 문서에서는 Gmail에서 작업을 어떻게 선언하고 사용할 수 있는지에 대한 정보를 제공합니다.', 'rewritten': [{'role': 'user', 'content': 'Gmail 작업을 선언하는 방법에 대해 자세히 알고 싶은데, Declaring Actions 관련 자료는 어디서 찿을수 있나요?'}], 'queries': ['Gmail 작업을 선언하는 방법과 Declaring Actions 관련 자료는 어디서 찾을 수 있나요?', 'How can I declare actions for Gmail and where can I find resources related to Declaring Actions?'], 'search_results': ['Gmail 작업\nGmail은 schema.org 마크업을 사용하여 사용자 작업을 가속화하고 사용자가 이메일에서 필요로 하는 가장 중요한 정보를 강조합니다.\nGmail은 다음과 같은 유형의 작업 및 대화형 카드를 지원합니다.\n클릭 한 번으로 실행할 수 있는 거의 모든 항목에 대한 원클릭 작업 [https://developers.google.com/workspace/gmail/markup/reference/one-click-action?hl=ko]\n더 복잡한 상호작용을 위한 Go-to Action [https://developers.google.com/workspace/gmail/markup/reference/go-to-action?hl=ko]\n항공편 양방향 카드 [https://developers.google.com/workspace/gmail/markup/reference/flight-reservation?hl=ko]\nGmail 하이라이트\nGmail은 동일한 schema.org 마크업을 사용하여 이메일 내에서 가장 중요한 정보를 강조 표시하고 사용자가 이에 따라 조치를 취할 수 있도록 합니다.\n버스 강조 표시 [https://developers.google.com/workspace/gmail/markup/reference/bus-reservation?hl=ko]\n렌터카 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/rental-car?hl=ko]\n항공편 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/flight-reservation?hl=ko]\n티켓이 있는 이벤트의 이벤트 하이라이트 [https://developers.google.com/workspace/gmail/markup/reference/event-reservation?hl=ko]\n주문 [https://developers.google.com/workspace/gmail/markup/reference/order?hl=ko] 및 소포 배송 [https://developers.google.com/workspace/gmail/markup/reference/parcel-delivery?hl=ko] 쇼핑 관련 주요 사항', 'Source URL: https://developers.google.com/workspace/gmail/markup/actions/handling-action-requests\n\n이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\n작업 요청 처리\nbookmark_border\n이 페이지의 내용\n1단계: 요청 확인\n2단계: 작업 처리\n3단계: 응답 코드 반환\n추가 자료\n작업 선언 [https://developers.google.com/workspace/gmail/markup/actions/declaring-actions?hl=ko]에 설명된 대로 사용자가 인앱 작업과 상호작용하면 Google은 작업에 선언된 URL로 HTTP 요청을 보냅니다.\n다음 예에서는 비용 보고서에 관한 이메일에 ConfirmAction 버튼을 추가합니다.\n--- 탭: JSON-LD ---\n<script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "EmailMessage",\n  "potentialAction": {\n    "@type": "ConfirmAction",\n    "name": "Approve Expense",\n    "handler": {\n      "@type": "HttpActionHandler",\n      "url": "https://myexpenses.com/approve?expenseId=abc123"\n    }\n  },\n  "description": "Approval request for John\'s $10.13 expense for office supplies"\n}\n</script>', 'Source URL: https://developers.google.com/workspace/gmail/markup/actions/declaring-actions\n\n이 페이지는 Cloud Translation API [https://cloud.google.com/translate/?hl=ko]를 통해 번역되었습니다.\nSwitch to English\n홈 [https://developers.google.com/?hl=ko]\nGoogle Workspace [https://developers.google.com/workspace?hl=ko]\nGmail [https://developers.google.com/workspace/gmail?hl=ko]\n가이드 [https://developers.google.com/workspace/gmail/api/guides?hl=ko]\n의견 보내기\n작업 선언\nbookmark_border\n이 페이지의 내용\n바로가기 작업\n모바일 딥 링크\n인앱 액션 수\n만료되는 작업\n추가 자료\nschema.org의 작업은 구조화된 데이터에서 실행할 수 있는 동사 또는 활동을 나타냅니다. 여러 유형의 작업 [https://developers.google.com/workspace/gmail/markup/actions/actions-overview?hl=ko]이 지원되며 모두 유사한 구조화된 데이터로 정의할 수 있습니다.\n바로가기 작업\nschema.org 항목을 사용하여 콘텐츠에 마크업을 추가하는 경우 해당 항목에 이동 작업을 추가할 수 있습니다. 예를 들어 EmailMessage 항목에 ViewAction 바로가기 링크를 추가하려면 다음 예와 같이 이메일의 potentialAction 속성을 채웁니다.\n--- 탭: JSON-LD ---\n<script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "EmailMessage",\n  "potentialAction": {\n    "@type": "ViewAction",\n    "target": "https://watch-movies.com/watch ...
# 평가 데이터셋 준비 완료
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_input          20 non-null     object
#  1   retrieved_contexts  20 non-null     object
#  2   response            20 non-null     object
#  3   reference           20 non-null     object
# dtypes: object(4)
# memory usage: 772.0+ bytes

# %%
### RAGAS 평가 실행

# LLM 래퍼 생성
evaluator_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
evaluator_llm = LangchainLLMWrapper(evaluator_llm)

# 평가 메트릭 정의
metrics = [
    LLMContextRecall(),  # 검색된 컨텍스트의 회수율
    Faithfulness(),  # 생성된 답변의 충실도
    FactualCorrectness()  # 사실적 정확성
]
# 평가 실행

result = evaluate(
    dataset=ragas_evaluated_dataset,
    metrics=metrics,
    llm=evaluator_llm,
)

print(result)
# 결과를 DataFrame으로 변환
result_df = result.to_pandas()

# 결과 저장
# result_df.to_csv('ragas_evaluation_result_hybrid4.csv', index=False)

display(result_df.head())
result_df[['context_recall', 'faithfulness', 'factual_correctness(mode=f1)']].describe()
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# {'context_recall': 0.9250, 'faithfulness': 0.8906, 'factual_correctness(mode=f1)': 0.5415}
#                                           user_input  \
# 0       CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?
# 1                      클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?
# 2                                    범위 많으면 동의 어렵나요?
# 3  As a beginner who is not familiar with Google ...
# 4  firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Fire...
#
#                                   retrieved_contexts  \
# 0  [except (OSError, IOError) as error:\n    prin...
# 1  [Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많...
# 2  [Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많...
# 3  [또한 사용자 계정 또는 서비스 계정이 모든 클라이언트에서 보유할 수 있는 총 새로...
# 4  [Cloud Functions로 Firestore 확장\n\nbookmark_bor...
#
#                                             response  \
# 0  CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 다음과 같은 작업이 필요합니...
# 1  Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 ...
# 2  "(범위가 많으면 동의가 어려운지)"는 제가 모르는 내용입니다. 일상 질문 혹은 구...
# 3  When Google Cloud session control features are...
# 4  Cloud Firestore에서 문서가 변경될 때마다 자동으로 실행되는 함수를 작성...
#
#                                            reference  context_recall  \
# 0  CSV 파일을 처리하는 함수에서는 사용자의 인증서를 나열하고, 기본 인증서가 만료되...             1.0
# 1  Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 ...             1.0
# 2          요청된 범위 수가 많으면 사용자 동의를 얻을 가능성이 낮아질 수 있습니다.             0.0
# 3  When Google Cloud session control features are...             1.0
# 4  Cloud Firestore에서 특정 문서의 모든 변경에 이벤트를 트리거하려면 on...             1.0
#
#    faithfulness  factual_correctness(mode=f1)
# 0      1.000000                          0.42
# 1      1.000000                          0.60
# 2      0.000000                          0.00
# 3      1.000000                          0.67
# 4      0.894737                          0.58
#        context_recall  faithfulness  factual_correctness(mode=f1)
# count        20.00000     20.000000                     20.000000
# mean          0.92500      0.890570                      0.541500
# std           0.24468      0.250809                      0.277285
# min           0.00000      0.000000                      0.000000
# 25%           1.00000      0.973684                      0.395000
# 50%           1.00000      1.000000                      0.590000
# 75%           1.00000      1.000000                      0.670000
# max           1.00000      1.000000                      1.000000

# %%
display(result_df)
# Out:
#                                            user_input  \
# 0        CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 어떤 작업이 필요한가요?
# 1                       클라우드 파이어스토어 부하 분산기 어떻게 써야되나요?
# 2                                     범위 많으면 동의 어렵나요?
# 3   As a beginner who is not familiar with Google ...
# 4   firebase_functions 어떻게 쓰는지 잘 모르겠는데, Cloud Fire...
# 5   Firebase에서 다단계 인증(MFA)을 사용할 때 Objective-C로 사용자...
# 6       Java를 사용해서 Firestore에 문서를 추가할 때 어떤 코드를 사용하나요?
# 7                   COLUMNS가 Dimension API에서 무슨 뜻인가요?
# 8                          ttll이 뭐에요? 그리고 한도 같은거 있나요?
# 9   Me want know what FUNCTION_ENTRYPOINT do in gc...
# 10                     Google 피트니스 심박수 데이터 읽기 권한 범위는?
# 11    projets.databeses.gte 메서드 쓸때 HTTP 리퀘스트 포맷이 뭐에요?
# 12  Google Developers Console을 활용하여 YouTube Data A...
# 13  firsetore users 데이타 가져오려면 어떻게하나요? users 콜렉션에서 ...
# 14                    Python에서 Cloud Firestore 초기화 방법
# 15  BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하고자 할 때, ...
# 16                         itemDownlodRestrction 뭐에요?
# 17  What does the textFormat field represent in Tr...
# 18                                 fileId는 무엇을 의미하나요?
# 19  Gmail 작업을 선언하는 방법에 대해 자세히 알고 싶은데, Declaring Ac...
#
#                                    retrieved_contexts  \
# 0   [except (OSError, IOError) as error:\n    prin...
# 1   [Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많...
# 2   [Cloud Firestore의 분할은 필요할 때 또는 키 공간이 확장될 때 더 많...
# 3   [또한 사용자 계정 또는 서비스 계정이 모든 클라이언트에서 보유할 수 있는 총 새로...
# 4   [Cloud Functions로 Firestore 확장\n\nbookmark_bor...
# 5   [Firebase Authentication with Identity Platfor...
# 6   [Firestore는 컬렉션에 저장되는 문서에 데이터를 저장합니다.\n문서에 데이터...
# 7   [COLUMN_NAME: 임베딩 데이터가 포함된 열의 이름입니다. 이 열은 ARRA...
# 8   [TtlConfig\n\nThe TTL (time-to-live) configura...
# 9   [--- 탭: gcloud [https://cloud.google.com/fires...
# 10  [https://www.googleapis.com/auth/fitness.body_...
# 11  [Gets multiple documents.Documents returned by...
# 12  [YouTube에서 Shorts 동영상의 조회수를 집계하는 방식에 맞게 Data A...
# 13  [users_ref = firestore.col collection_path\nus...
# 14  [참고: 코드 샘플에서는 여러 언어를 다루지만 샘플을 설명하는 텍스트는 웹 메서드 ...
# 15  [입력: 표에서 데이터를 읽거나 특정 열을 선택\n조인: JOIN 조건을 기반으로 ...
# 16  [inheritedPermissionsDisabled\nboolean\n이 파일에 ...
# 17  [스코어카드 차트의 숫자 키/기준 값에 대한 맞춤 형식 지정 옵션입니다. 이 필드는...
# 18  [| Fields |\n| --- |\n| target_id | int32 The ...
# 19  [Gmail 작업\nGmail은 schema.org 마크업을 사용하여 사용자 작업을...
#
#                                              response  \
# 0   CSV 파일을 이용해서 S/MIME 인증서를 관리하려면 다음과 같은 작업이 필요합니...
# 1   Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 ...
# 2   "(범위가 많으면 동의가 어려운지)"는 제가 모르는 내용입니다. 일상 질문 혹은 구...
# 3   When Google Cloud session control features are...
# 4   Cloud Firestore에서 문서가 변경될 때마다 자동으로 실행되는 함수를 작성...
# 5   Objective-C에서 Firebase 다단계 인증(MFA) 사용자를 인증하는 방...
# 6   Java를 사용하여 Firestore에 문서를 추가하는 방법은 다음과 같습니다. 아...
# 7   Dimension API에서 "COLUMNS"는 시트의 열에서 작동하는 것을 의미합...
# 8   TTL(Time-to-Live)은 문서의 수명을 설정하는 구성입니다. TTL이 활성...
# 9   In the `gcloud run deploy` command, the `FUNCT...
# 10  Google 피트니스에서 심박수 데이터를 읽기 위해 필요한 OAuth 2.0 범위는...
# 11  죄송하지만, "projets.databeses.gte" 메서드에 대한 정보는 제공된...
# 12  YouTube Data API를 사용 설정하기 위해 Google Developers...
# 13  Firestore에서 `users` 컬렉션의 모든 사용자 데이터를 가져오려면 `ge...
# 14  Python에서 Cloud Firestore를 초기화하는 방법은 다음과 같습니다:\...
# 15  BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하려면 'para...
# 16  'itemDownloadRestriction'은 파일의 다운로드 제한사항을 확인하는...
# 17  The `textFormat` field in the JSON representat...
# 18  'fileId'는 Google Drive API에서 파일의 고유 식별자를 의미합니다...
# 19  Gmail 작업을 선언하는 방법에 대한 자세한 내용은 "작업 선언(Declaring...
#
#                                             reference  context_recall  \
# 0   CSV 파일을 처리하는 함수에서는 사용자의 인증서를 나열하고, 기본 인증서가 만료되...             1.0
# 1   Cloud Firestore는 데이터베이스에 대한 트래픽을 지원하기 위해 자동으로 ...             1.0
# 2           요청된 범위 수가 많으면 사용자 동의를 얻을 가능성이 낮아질 수 있습니다.             0.0
# 3   When Google Cloud session control features are...             1.0
# 4   Cloud Firestore에서 특정 문서의 모든 변경에 이벤트를 트리거하려면 on...             1.0
# 5   다단계 인증(MFA) 사용 시 Firebase에서 사용자 인증을 완료하는 방법은 F...             1.0
# 6   다음은 Java에서 Firestore에 문서를 추가할 때 사용하는 코드 예시입니다....             0.5
# 7        COLUMNS는 Dimension API에서 시트의 열에서 작동함을 의미합니다.             1.0
# 8   컬렉션 그룹당 하나의 필드만 TTL 필드로 표시할 수 있고, 필드 수준 구성은 최대...             1.0
# 9   FUNCTION_ENTRYPOINT는 gcloud run deploy 명령어에서 함...             1.0
# 10  Google 피트니스에서 심박수 데이터를 확인하기 위해 필요한 OAuth 2.0 범...             1.0
# 11  HTTP 요청 형식은 다음과 같습니다:\r\n```\r\nGET https://fi...             1.0
# 12  YouTube Data API를 사용 설정하기 위한 첫 번째 단계는 Google D...             1.0
# 13  Firestore에서 users 콜렉션의 모든 users 정보를 가져오려면 다음과 ...             1.0
# 14  Cloud Firestore를 Python에서 서비스 계정을 사용하여 초기화하려면 ...             1.0
# 15  BigQuery에서 쿼리 실행 단계의 병렬 입력 세그먼트 수를 확인하려면 'para...             1.0
# 16  itemDownloadRestriction 필드는 소유자 또는 주최자가 직접 적용한...             1.0
# 17  The textFormat field specifies the text format...             1.0
# 18                             fileId는 파일의 ID를 의미합니다.             1.0
# 19  작업 선언 방법에 대한 자세한 내용은 작업 선언(Declaring Actions) ...             1.0
#
#     faithfulness  factual_correctness(mode=f1)
# 0       1.000000                          0.42
# 1       1.000000                          0.60
# 2       0.000000                          0.00
# 3       1.000000                          0.67
# 4       0.894737                          0.58
# 5       1.000000                          0.64
# 6       1.000000                          0.17
# 7       1.000000                          1.00
# 8       1.000000                          0.55
# 9       0.500000                          0.40
# 10      1.000000                          1.00
# 11      0.666667                          0.57
# 12      1.000000                          0.67
# 13      1.000000                          0.38
# 14      1.000000                          0.67
# 15      0.750000                          0.75
# 16      1.000000                          0.67
# 17      1.000000                          0.80
# 18      1.000000                          0.29
# 19      1.000000                          0.00
